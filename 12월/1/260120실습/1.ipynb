# %% [markdown]
# ## 데이터 불러오기 및 전처리

# %%
from hossam import load_data
from pandas import DataFrame, get_dummies
from matplotlib import pyplot as plt
from matplotlib import font_manager as fm 
import seaborn as sb
import numpy as np
import statsmodels.api as sm
from sklearn.metrics import confusion_matrix, roc_curve, accuracy_score, recall_score,  precision_score, f1_score
from statsmodels.stats.outliers_influence import variance_inflation_factor
import pandas as pd

# %%
origin = pd.read_csv(
    "/Users/gyulltang/Desktop/vscode/ipynb/12월/open API/기후에너지환경부 온실가스종합정보센터_국가 온실가스 인벤토리 배출량_20211229.csv",
    encoding="cp949"
)
origin.head()
# Out:
#           분야 및 연도      1990      1991      1992      1993      1994      1995  \
# 0  총배출량(Gg CO2eq)  292097.8  315341.5  343337.6  378532.9  403541.2  433757.3
# 1            순배출량  254424.5  281879.1  310662.4  347664.4  370444.7    402460
# 2             에너지  240294.5  258113.2  278995.6  308499.8  327799.7  352000.7
# 3          A 연료연소  235182.2  253554.5  275205.9  305340.3  325066.6  349613.2
# 4  A 연료연소_1 에너지산업   48351.2   54790.1   62374.9   68765.1   83606.2   91684.7
#
#        1996      1997      1998  ...      2010      2011      2012      2013  \
# 0  470241.2  501875.2  431387.6  ...  656048.8  684703.4  688035.3  697308.8
# 1  435519.1    462376  383326.7  ...    601295  631443.4  639994.1  653919.2
# 2  385582.1  411617.6  351493.3  ...  565692.1  594655.1  596004.2    604525
# 3  383185.8  409141.4  349141.9  ...  561911.8  590614.5  591653.6  600054.7
# 4  108977.8  122325.2  106295.2  ...  254797.3  262387.6  266405.6  272977.1
#
#        2014      2015      2016      2017      2018      2019
# 0  692100.7    692576  693612.5  710743.4  727045.2  701370.4
# 1  647718.7  647012.4  647071.3    668186    684959  661820.1
# 2  596943.4  600256.4  602213.7  615604.6  632571.9  611499.1
# 3  592851.5  596492.3    598317  611628.1  628144.7  607301.6
# 4  258467.4  260499.4  262104.3  269764.3  286398.7  266224.6
#
# [5 rows x 31 columns]

# %%
origin.shape
origin.head()
origin.columns
origin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 31 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   분야 및 연도  144 non-null    object
#  1   1990     126 non-null    object
#  2   1991     121 non-null    object
#  3   1992     122 non-null    object
#  4   1993     122 non-null    object
#  5   1994     123 non-null    object
#  6   1995     123 non-null    object
#  7   1996     123 non-null    object
#  8   1997     124 non-null    object
#  9   1998     124 non-null    object
#  10  1999     124 non-null    object
#  11  2000     124 non-null    object
#  12  2001     124 non-null    object
#  13  2002     124 non-null    object
#  14  2003     124 non-null    object
#  15  2004     124 non-null    object
#  16  2005     124 non-null    object
#  17  2006     124 non-null    object
#  18  2007     124 non-null    object
#  19  2008     124 non-null    object
#  20  2009     124 non-null    object
#  21  2010     125 non-null    object
#  22  2011     125 non-null    object
#  23  2012     125 non-null    object
#  24  2013     125 non-null    object
#  25  2014     123 non-null    object
#  26  2015     123 non-null    object
#  27  2016     123 non-null    object
#  28  2017     123 non-null    object
#  29  2018     123 non-null    object
#  30  2019     123 non-null    object
# dtypes: object(31)
# memory usage: 35.0+ KB

# %% [markdown]
# 연도칼럼 리스트 만듬

# %%
year_cols = origin.columns[1:]  # '1990' ~ '2019'

# %% [markdown]
# melt

# %%
df_long = origin.melt(
    id_vars='분야 및 연도',
    value_vars=year_cols,
    var_name='연도',
    value_name='배출량'
)

# %%
df_long.shape
df_long.head()
df_long.columns
df_long.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4320 entries, 0 to 4319
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   분야 및 연도  4320 non-null   object
#  1   연도       4320 non-null   object
#  2   배출량      3710 non-null   object
# dtypes: object(3)
# memory usage: 101.4+ KB

# %%
df_long['분야'] = df_long['분야 및 연도'].str.strip()

# %% [markdown]
# 6-1. 연도별 총배출량

# %%
yearly = (
    df_long
    .groupby('연도', as_index=False)['배출량']
    .sum()
)

# %%
yearly
# Out:
#       연도                                                배출량
# 0   1990  292097.8254424.5240294.5235182.248351.236575.3...
# 1   1991  315341.5281879.1258113.2253554.554790.142684.3...
# 2   1992  343337.6310662.4278995.6275205.962374.95011211...
# 3   1993  378532.9347664.4308499.8305340.368765.156338.8...
# 4   1994  403541.2370444.7327799.7325066.683606.271011.1...
# 5   1995  433757.3402460352000.7349613.291684.7786881236...
# 6   1996  470241.2435519.1385582.1383185.8108977.895316....
# 7   1997  501875.2462376411617.6409141.4122325.2107294.3...
# 8   1998  431387.6383326.7351493.3349141.9106295.2911141...
# 9   1999  469368.6413819.4382112.8379577.1116150.2100604...
# 10  2000  502681.5443704.4411584.7408915.3136124.2120214...
# 11  2001  515955457546425928.7423225.1147477131396.31372...
# 12  2002  538405.9482275445254.6442541.4155764.3140828.4...
# 13  2003  548761.8493177.5452962.6450177.7159992.5144871...
# 14  2004  557011.8500145.3460070.5457010.2172849.3156494...
# 15  2005  561472.1506510.3469372.5466261.4179003.7162906...
# 16  2006  566997.8510828.9474784.8471614.5185847.1170054...
# 17  2007  580340.8523528492405489010.9197249.6181313.113...
# 18  2008  593991.2536386.1506555503103.2210717.6192998.1...
# 19  2009  598001.3540874513041.7509794.8229409212377.714...
# 20  2010  656048.8601295565692.1561911.8254797.3239287.6...
# 21  2011  684703.4631443.4594655.1590614.5262387.6246092...
# 22  2012  688035.3639994.1596004.2591653.6266405.6249479...
# 23  2013  697308.8653919.2604525600054.7272977.1256140.3...
# 24  2014  692100.7647718.7596943.4592851.5258467.4241712...
# 25  2015  692576647012.4600256.4596492.3260499.4242127.8...
# 26  2016  693612.5647071.3602213.7598317262104.3242482.4...
# 27  2017  710743.4668186615604.6611628.1269764.3251381.5...
# 28  2018  727045.2684959632571.9628144.7286398.7268355.6...
# 29  2019  701370.4661820.1611499.1607301.6266224.6248745...

# %% [markdown]
# ## 위키피디아

# %% [markdown]
# 가스별 정의 텍스트 수집

# %%
import wikipedia

wikipedia.set_lang("en")

page = wikipedia.page("Greenhouse gas")
text = page.content

print(text[:2000])
# Out:
# Greenhouse gases (GHGs) are the gases in an atmosphere that trap heat, raising the surface temperature of astronomical bodies such as Earth. Unlike other gases, greenhouse gases absorb the radiations that a planet emits, resulting in the greenhouse effect. The Earth is warmed by sunlight, causing its surface to radiate heat, which is then mostly absorbed by greenhouse gases. Without greenhouse gases in the atmosphere, the average temperature of Earth's surface would be about −18 °C (0 °F), rather than the present average of 15 °C (59 °F). Human-induced warming has been increasing at a rate that is unprecedented in the instrumental record, reaching 0.27 [0.2–0.4] °C per decade over 2015–2024. This high rate of warming is caused by a combination of greenhouse gas emissions being at an all-time high of 53.6±5.2 Gt CO2e yr−1 over the last decade (2014–2023), as well as reductions in the strength of aerosol cooling.
# The five most abundant greenhouse gases in Earth's atmosphere, listed in decreasing order of average global mole fraction, are: water vapor, carbon dioxide, methane, nitrous oxide, ozone. Other greenhouse gases of concern include chlorofluorocarbons (CFCs and HCFCs), hydrofluorocarbons (HFCs), perfluorocarbons, SF6, and NF3. Water vapor causes about half of the greenhouse effect, acting in response to other gases as a climate change feedback.
# Human activities since the beginning of the Industrial Revolution (around 1750) have increased carbon dioxide by over 50%, and methane levels by 150%. Carbon dioxide emissions are causing about three-quarters of global warming, while methane emissions cause most of the rest. The vast majority of carbon dioxide emissions by humans come from the burning of fossil fuels, with remaining contributions from agriculture and industry. Methane emissions originate from agriculture, fossil fuel production, waste, and other sources. The carbon cycle takes thousands of years to fully absorb CO2 from the atmosphere, while methane las

# %%
import wikipedia
wikipedia.set_lang("en")

topics = {
    "Carbon dioxide": "Carbon dioxide",
    "Methane": "Methane",
    "Nitrous oxide": "Nitrous oxide"
}

wiki_text = {}

for key, title in topics.items():
    page = wikipedia.page(title, auto_suggest=False)
    wiki_text[key] = page.content

# %%
{
  "Carbon dioxide": "...",
  "Methane": "...",
  "Nitrous oxide": "..."
}
# Out:
# {'Carbon dioxide': '...', 'Methane': '...', 'Nitrous oxide': '...'}

# %%
import wikipedia
wikipedia.set_lang("en")

page = wikipedia.page("Greenhouse gas inventory")
wiki_text_en = page.content

# %% [markdown]
# 한국어 번역 방법<br>
# googletrans

# %%
from deep_translator import GoogleTranslator

def split_text(text, max_length=4000):
    chunks = []
    start = 0
    while start < len(text):
        end = start + max_length
        chunks.append(text[start:end])
        start = end
    return chunks

# %%
chunks = split_text(wiki_text_en, max_length=4000)
len(chunks)
# Out:
# 7

# %%
from deep_translator import GoogleTranslator

translator = GoogleTranslator(source='en', target='ko')

translated_chunks = []

for chunk in chunks:
    translated = translator.translate(chunk)
    translated_chunks.append(translated)

wiki_text_ko = "\n".join(translated_chunks)

# %%
formatted_text = wiki_text_ko.replace(". ", ".\n")
print(formatted_text)
# Out:
# 온실가스 인벤토리는 다양한 이유로 개발된 온실가스 배출의 배출 인벤토리입니다.
#  과학자들은 대기 모델을 개발할 때 자연 및 인위적(인위적) 배출 목록을 도구로 사용합니다.
#  정책 입안자들은 인벤토리를 사용하여 배출 감소를 위한 전략과 정책을 개발하고 해당 정책의 진행 상황을 추적합니다.
# 규제 기관과 기업은 또한 허용 가능한 배출율에 대한 규정 준수 기록을 수립하기 위해 목록에 의존합니다.
#  기업, 대중 및 기타 이익 집단은 배출량의 출처와 추세를 더 잘 이해하기 위해 목록을 사용합니다.
# 다른 대기 배출 인벤토리와 달리 온실가스 인벤토리에는 배출원 범주의 배출량뿐만 아니라 탄소 흡수원에 의한 제거도 포함됩니다.
#  이러한 제거를 일반적으로 탄소 격리라고 합니다.
# 온실가스 인벤토리는 일반적으로 지구 온난화 지수(GWP) 값을 사용하여 다양한 온실가스 배출량을 단일 가중치 배출량 값으로 결합합니다.
#
#
# == 예시 ==
# 온실가스 인벤토리의 주요 사례는 다음과 같습니다.
#
# 모든 부속서 I 국가는 유엔기후변화협약(UNFCCC)에 따라 온실가스의 연간 배출량과 흡원을 보고해야 합니다.
# UNFCCC 및/또는 교토 의정서 당사국인 국가 정부는 배출원에서 발생하는 모든 인위적 온실가스 배출 및 흡수원에서 제거되는 양에 대한 연간 목록을 제출해야 합니다.
# 교토 의정서에는 의정서 제5조 및 제8조 준수 여부를 결정하기 위한 국가 목록 시스템, 목록 보고 및 연간 목록 검토에 대한 추가 요구 사항이 포함되어 있습니다.
# 교토 의정서의 청정 개발 메커니즘에 따른 프로젝트 개발자는 프로젝트 기준의 일부로 목록을 준비합니다.
#
#
# == 온실가스 배출회계 ==
#
# 온실가스 배출 회계는 특정 기간 동안 정부(보통 국가, 때로는 지역 또는 도시)가 배출한 온실가스(GHG)의 양을 측정하는 것입니다.
# 이러한 조치는 기후 과학 및 기후 정책을 수행하는 데 사용됩니다.
# GHG 배출량을 측정하는 방법에는 생산 기반(영토 기반이라고도 함)과 소비 기반이라는 두 가지 주요 상충되는 방법이 있습니다.
# 기후 변화에 관한 정부 간 패널은 생산 기반 배출을 "국가가 관할권을 갖고 있는 국토 및 연안 지역 내에서" 발생하는 것으로 정의합니다.
# 소비 기반 배출량은 국내 최종 소비로 인한 배출량과 수입품 생산으로 인한 배출량을 포함하여 무역의 영향을 고려합니다.
# 따라서 무역의 관점에서 소비 기반 배출 회계는 수출을 포함하지만 수입을 제외하는 생산 기반 배출 회계와 반대입니다(표 1).
# 각 측정 방법이 매우 다른 결과를 생성할 수 있으므로 회계 방법의 선택은 정책 결정에 매우 중요한 영향을 미칠 수 있습니다.
# 따라서 국가 온실가스 배출 인벤토리(NEI)의 값이 다르면 국가가 서로 다른 최적의 완화 활동을 선택하게 될 수 있으며, 잘못된 정보에 기초한 잘못된 선택은 잠재적으로 해를 끼칠 수 있습니다.
# 생산 기반 배출 회계의 적용은 측정하기가 더 쉽기 때문에 현재 정책 측면에서 선호되지만, 주로 국제 무역/운송에 포함된 배출량을 할당할 수 없고 탄소 누출 가능성이 있다는 이유로 문헌에서 비판을 받고 있습니다.
# 전 세계 거의 모든 국가는 파리 협약의 당사국입니다.
# 이 협정에서는 국가적으로 결정된 기여와 기후 정책, EU 배출권거래제(ETS)와 같은 지역 기후 정책, 그리고 지구 온난화를 제한하는 세계의 진행 상황을 추적하기 위해 UNFCCC(유엔 기후 변화 협약)에 정기적인 생산 기반 온실가스 배출 목록을 제공하도록 요구합니다.
#
#
# === 생산기준과 소비기준의 비교
# 회계 ===
#
# 지난 수십 년 동안 배출량은 1990년대 전반에 걸쳐 연 1.0%에서 2000년과 2008년 사이에 연 3.4%로 증가했습니다.
# 이러한 증가는 전 세계 인구 및 1인당 GDP의 증가뿐 아니라 GDP의 에너지 집약도(단위 GDP당 에너지) 및 에너지의 탄소 집약도(단위 에너지당 배출량)의 전 세계적 증가에 의해 주도되었습니다.
# 이러한 동인은 개발도상국 시장(교토 비부속서 B 국가)에서 가장 뚜렷하게 나타나지만, 이들 국가에서 성장의 상당 부분이 선진국(교토 부속서 B 국가) 소비자의 수요를 충족시키는 것이라는 점은 덜 분명합니다.
# 이는 배출 정책이 덜 엄격한 비부속서 B 국가로부터 제품 수입을 늘리는 대신 부속서 B 국가가 국내 생산량을 줄이는 탄소 누출로 알려진 과정에 의해 과장됩니다.
# 지역 오염물질을 고려할 때 이는 소비자의 합리적인 선택으로 보일 수 있지만, 소비자는 어디에서 생산되든 온실가스 등 글로벌 오염물질의 영향을 피할 수 없습니다.
# 2008년 금융 위기 동안 배출량이 증가했지만 장기적인 배출량 증가 추세가 재개되었습니다.
# 오늘날, 온실가스의 인위적 방출을 늦추고 그에 따른 기후 변화를 늦추기 위해 많은 국제적 노력이 투입되고 있습니다.
# 국제 및 지역 정책에 대한 벤치마크 및 배출 목표를 설정하고 진행 상황을 모니터링 및 평가하려면 각 국가의 NEI를 정확하게 측정하는 것이 필수적입니다.
#
#
# === 생산기준회계 ===
#
# 생산 기반 배출 회계는 현재 정책 측면에서 선호되기 때문에 그 방법론은 잘 확립되어 있습니다.
# 배출량은 온실가스 보고를 위해 IPCC가 발행한 2006년 지침에 따라 화석 연료 사용 및 산업, 농업 등 기타 관련 프로세스에서 직접적으로 계산되지 않고 간접적으로 계산됩니다.
# 지침은 정교함 수준에 따라 다양한 방법론을 포괄합니다(표 2의 계층 1~3).
# 가장 간단한 방법론은 인간 활동의 범위와 '배출계수'로 알려진 해당 활동으로 인한 배출량을 정량화하는 계수를 결합합니다.
# 예를 들어, 에너지 부문의 배출량을 추정하기 위해(선진국에서는 일반적으로 CO2 배출량의 90% 이상, 전체 GHG 배출량의 75%를 차지함) 연소되는 연료의 양을 배출 계수와 결합합니다.
# 정교함의 수준은 배출 계수의 정확성과 복잡성에 따라 증가합니다.
# 표 2는 영국이 배출량 생성 활동 중 일부를 추정하기 위해 이러한 지침을 구현하는 방법을 간략하게 설명합니다.
#
# 나무 연소로 인한 배출은 나무가 태워진 국가가 아닌 나무가 베어진 국가를 기준으로 계산됩니다.
#
#
# === 소비 기반 회계 ===
# 소비 기반 배출 회계에는 입출력 테이블을 사용하여 동일하게 확립된 방법론이 있습니다.
# 이는 "다양한 생산 부문 간의 상호 연결을 표시하고 경제의 생산 및 소비 추적을 허용"하며 원래 국가 경제를 위해 만들어졌습니다.
# 그러나 생산이 점점 더 국제화되고 국가 간 수출입 시장이 활발해지면서 MRIO(다지역 입출력) 모델이 개발되었습니다.
# MRIO의 고유한 기능은 생산 주기 전반에 걸쳐 제품을 추적할 수 있도록 하여 "모델에 표시된 다양한 국가의 다양한 경제 부문에서 제품 가치에 대한 기여도를 정량화합니다.
# 따라서 소비되는 제품의 글로벌 공급망에 대한 설명을 제공합니다".
# 이를 통해 생산량 단위당 CO2 배출량에 대한 지역 및 산업별 데이터를 사용할 수 있다고 가정하면 제품의 총 배출량을 계산할 수 있으므로 최종 소비자에게 할당된 배출량은 책임입니다.
# 배출 회계의 두 가지 방법론은 주요 차이점을 드러내기 시작합니다.
# 생산 기반 회계는 GDP와 투명하게 일치하는 반면, 소비는
# 기반 회계(더 복잡하고 불확실함)는 국가 소비 및 무역과 일치합니다.
# 그러나 가장 중요한 차이점은 후자가 생산 기반 회계에서 생략된 '내재된' 배출량을 포함하여 글로벌 배출량을 다루고 글로벌 기반 완화 옵션을 제공한다는 것입니다.
# 따라서 국제 무역에 포함된 배출량의 귀속이 문제의 핵심입니다.
#
#
# === 국제 무역으로 인한 배출 ===
#
# 그림 1과 표 3은 국제 무역에 포함된 배출 정도와 배출 감소를 시도할 때 그 중요성을 보여줍니다.
# 그림 1은 2004년 무역 흐름이 가장 큰 상위 10개 국가의 국제 무역 흐름을 보여주며, 개발도상국(주로 중국, 러시아, 인도)에서 선진국(주로 미국, EU, 일본)으로의 무역 지배력을 보여줍니다.
# 표 3은 2008년에 거래된 배출량이 총 7.8기가톤(Gt)이고 개발도상국에서 선진국으로 순 CO2 배출량이 1.6Gt임을 보여주는 것을 뒷받침합니다.
# 표 3은 또한 이러한 생산, 소비 및 무역 과정이 1990년(일반적으로 기준 수준으로 선택됨)부터 2008년까지 어떻게 변화했는지 보여줍니다.
# 전 세계 배출량은 39% 증가했지만 같은 기간 선진국은 국내 배출량을 안정화한 반면 개발도상국의 국내 배출량은 두 배로 늘었습니다.
# 그러나 개발도상국에서 선진국으로의 무역 증가를 고려하면 이러한 '안정화'는 틀림없이 오해를 불러일으킬 수 있습니다.
# 이는 0.4Gt CO2에서 1.6Gt CO2로 증가했습니다.
# 이는 연 평균 17% 증가로 1990년부터 2008년 사이에 16Gt CO2가 개발도상국에서 선진국으로 거래되었음을 의미합니다.
# 개발도상국의 생산량 증가 중 일부가 선진국의 소비 수요를 충족시키기 위한 것이라고 가정하면 탄소 누출로 알려진 과정이 분명해집니다.
# 따라서 국제 무역(즉, 소비 기반 회계 방법론)을 포함하면 선진국의 명백한 배출량 감소 추세가 반전되어 해당 기간에 걸쳐 2% 감소(생산 기반 회계로 계산)가 7% 증가로 변경됩니다.
# 이 점은 이러한 경향이 덜 집계된 규모로 연구될 때 더욱 강조됩니다.
#
# 그림 2는 소비 기반 회계에 비해 생산 기반 회계로 계산된 배출 잉여 비율을 보여줍니다.
# 일반적으로 생산 기반 회계에서는 EU 및 OECD 국가(선진국)에 대해 더 낮은 배출량을 제안하고 BRIC 및 기타 국가(개발도상국)에 대해 더 높은 배출량을 제안합니다.
# 그러나 소비 기반 회계에서는 BRIC 및 RoW의 배출량이 더 적고 EU 및 OECD 국가의 배출량이 더 높은 반대의 경우를 제안합니다.
# 이로 인해 Boitier는 EU 및 OECD를 'CO2 소비자'로, BRIC 및 RoW를 'CO2 생산자'로 명명했습니다.
# 이러한 결과의 큰 차이는 추가 분석을 통해 확증됩니다.
# 1994년 EU-27에서는 소비 기반 접근 방식을 사용하여 계산한 배출량보다 11% 더 높게 계산했으며, 이 차이는 2008년에는 24%로 증가했습니다.
# 마찬가지로 OECD 국가는 2006년에 16%의 최고 변동에 도달했지만 2008년에는 14%로 떨어졌습니다.
# 이와 대조적으로 RoW는 상대적으로 시작하고 끝나지만 그 사이에는 BRIC과 마찬가지로 분명한 CO2 생산자입니다.
# 생산 기반 배출량에 비해 평균 소비 기반 배출량 적자는 18.5%입니다.
# Peters와 Hertwich는 2001년 GTAP(Global Trade Analysis Program)의 데이터를 사용하여 국제 무역에 포함된 배출량을 계산하기 위한 MRIO 연구를 완료했습니다.
# 조작 후에는 그 수치가 Boitier보다 약간 더 보수적이지만(EU 14%, OECD 3%, BRIC 16%, RoW 6%) 동일한 경향이 분명합니다.
# 선진국은 CO2 소비자이고 개발도상국은 CO2 생산자입니다.
# 이러한 추세는 문헌 전체에서 볼 수 있으며 정책 결정 결정에서 소비 기반 배출 회계의 사용을 뒷받침합니다.
#
#
# == 도구 및 표준 ==
#
#
# === ISO 14064 ===
# ISO 14064 표준(2006년에 발표됨)
# ly 2007)은 환경 관리에 대한 국제 표준인 ISO 14000 시리즈에 가장 최근에 추가된 것입니다.
# ISO 14064 표준은 정부, 기업, 지역 및 기타 조직에 온실가스 배출 측정, 정량화 및 감소를 목표로 하는 프로그램을 위한 통합 도구 세트를 제공합니다.
# 이러한 표준을 통해 조직은 세계적으로 인정받는 표준을 사용하여 배출권 거래 제도에 참여할 수 있습니다.
#
#
# === 지방 정부 운영 프로토콜 ===
# 지방 정부 운영 프로토콜(LGOP)은 지방 정부 운영 전반에 걸쳐 온실가스 배출량을 계산하고 보고하기 위한 도구입니다.
# 2008년 9월 캘리포니아 대기 자원위원회(ARB)가 지방 정부가 캘리포니아의 AB 32 온실가스 감축 의무를 충족하는 데 도움이 되는 일관된 GHG 목록을 개발하고 보고하도록 채택한 이 문서는 캘리포니아 기후 행동 등록소(California Climate Action Registry), 기후 등록소(The Climate Registry), ICLEI 및 수십 명의 이해관계자와의 협력을 통해 개발되었습니다.
# 캘리포니아 지속가능성 연합(California Sustainability Alliance)은 또한 LGOP 매뉴얼의 복잡성을 세분화하고 권장 인벤토리 프로토콜의 영역별 요약을 제공하는 지방 정부 운영 프로토콜 툴킷을 만들었습니다.
# 온실가스 배출 인벤토리의 IPCC 형식을 알아보세요
# GHG 배출 인벤토리의 데이터는 회원국과 UNFCCC(유엔 기후 변화 협약) 사무국 및 교토 의정서 간의 모든 통신과 마찬가지로 IPCC 형식(공통 보고 형식, CRF를 사용하여 표시되는 7개 부문)을 사용하여 표시됩니다.
#
#
# == 소비회계의 장점 ==
# 소비 기반 배출 회계는 현재 UNFCCC 우선 생산 기반 회계에서 무시되는 구체화된 배출량을 통합하므로 우수한 것으로 간주될 수 있습니다.
# 다른 주요 이점으로는 완화 옵션 확장, 참여 증가를 통해 더 많은 글로벌 배출량 포괄, 청정 개발 메커니즘(CDM)과 같은 정책을 본질적으로 포괄한다는 점 등이 있습니다.
#
#
# === 완화 옵션 확장 ===
# 생산 기반 시스템에서는 국가가 오염 집약적인 자원 기반을 보유하고 있다는 이유로 처벌을 받습니다.
# 이 국가가 CO2 배출량의 69%가 수출을 위한 생산의 결과인 노르웨이와 같이 오염 집약적인 수출을 하고 있는 경우, 교토에서 정한 배출량 감소를 충족하는 간단한 방법은 수출을 줄이는 것입니다.
# 이는 환경적으로는 유리하지만 수출은 국가 GDP의 중요한 부분을 차지하므로 경제적, 정치적으로 해로울 수 있습니다.
# 그러나 조화로운 세계세, 국경세 조정 또는 할당량과 같은 적절한 메커니즘을 마련함으로써 소비 기반 회계 시스템은 비교 우위를 환경 요인을 포함하는 결정으로 전환할 수 있습니다.
# 가장 많이 논의되는 세금은 제품을 생산하고 운송하는 데 사용되는 화석 연료의 탄소 함량을 기준으로 하며, 사용된 탄소 수준이 높을수록 더 많은 세금이 부과됩니다.
# 국가가 자발적으로 참여하지 않으면 국경세가 부과될 수 있습니다.
# 이 시스템은 제품 가격에 환경 부하 비용을 포함시키는 효과를 가지므로 시장 힘은 경제적, 환경적으로 바람직한 곳으로 생산을 이동시켜 온실가스 배출을 줄입니다.
#
#
# === 참여 확대 ===
# 직접적으로 배출량을 줄이는 것 외에도 이 시스템은 두 가지 방식으로 경쟁력 문제를 완화할 수 있습니다.
# 첫째, 국내 및 외국 생산자가 동일한 탄소세에 노출됩니다.
# 둘째, 여러 국가가 동일한 수출 시장을 놓고 경쟁하는 경우 마케팅 도구로 환경 성과를 홍보할 수 있습니다.
# 비부속서 B 국가에 대한 법적 구속력 있는 약속의 부재로 인한 경쟁력 상실은 배출량이 많은 두 국가인 미국과 호주가 원래 교토 의정서를 비준하지 않은 주된 이유였습니다(호주는 나중에 2007년에 비준함).
# 이러한 우려를 완화함으로써 더 많은 국가가 미래 기후 정책에 참여할 수 있습니다.
# 결과적으로 법적 구속력이 있는 감축 정책이 전 세계 배출량의 더 많은 비율을 차지하게 됩니다.
# 더욱이, 현재 선진국은 개발도상국보다 배출량을 더 많이 줄일 것으로 예상되므로, 선진국에 더 많은 배출량이 (공정하게) 귀속될수록 법적 구속력이 있는 감축 정책의 적용을 더 많이 받게 됩니다.
# Peters는 이 마지막 예측이 소비 기반 회계가 참여 증가와 관계없이 유리하게도 더 큰 배출량 감소를 가져온다는 것을 의미한다고 주장합니다.
# 부속서 I 국가들만이 2006년 IPCC 지침을 사용하는 반면, 부속서 I이 아닌 국가들은 여전히 ​​온실가스 배출 목록을 개발하는 과정에 있으므로 2006년 지침을 따를 필요가 없습니다.
#
#
# === CDM 등 정책 포괄 ===
# CDM은 EU ETS와 같은 거래 제도의 무역을 위한 '탄소 배출권' 생성을 목표로 교토 의정서에 따라 설정된 유연한 메커니즘입니다.
# 심한 비판에도 불구하고(Evans, p134-135; 및 Burniaux et al., p58-65 참조), 이론에 따르면 환경 저감의 한계 비용은 비부속서 B 국가에서 더 낮기 때문에 이와 같은 계획은 부속서 B에서 비부속서 B 국가로의 기술 이전을 촉진하여 배출량을 더 저렴하게 감소시킬 수 있다는 것입니다.
# 소비 기반 배출 회계 하에서는 국가가 수입으로 인한 배출에 책임이 있기 때문에 수입국이 좋은 환경 행동을 장려하고 수출국에서 사용할 수 있는 가장 깨끗한 생산 기술을 홍보하는 것이 중요합니다.
# 따라서 나중에 CDM이 추가된 교토 의정서와 달리 소비 기반 배출 회계는 배출량을 할당하는 방식으로 인해 본질적으로 외국의 청정 개발을 촉진합니다.
# 여전히 관련성이 있는 한 가지 허점은 선진국이 근본적인 문제를 완화하지 않고 단순히 개발도상국의 저감 잠재력을 활용하여 이를 상쇄하는 소비를 계속 늘리는 탄소 식민주의입니다.
#
#
# == 소비회계의 단점 ==
# 소비 기반 배출 회계는 장점에도 불구하고 단점이 없는 것은 아닙니다.
# 이러한 사항은 위와 표 1에서 강조되었으며, 원칙적으로 불확실성이 커지고 복잡성이 커져 항상 사용할 수 있는 데이터가 더 필요하지 않으며 더 큰 국제 협력이 필요합니다.
#
#
# === 불확실성과 복잡성 증가 ===
# 불확실성은 세 가지 주요 이유에서 비롯됩니다.
# 생산 기반 회계는 더 확실한 통계 소스 및 GDP에 훨씬 더 가깝습니다.
# 소비 기반 회계의 방법론에는 생산 기반 회계에 비해 추가 단계가 필요하며, 이 단계는 본질적으로 더 많은 의심을 불러일으킵니다.
# 소비 기반 회계에는 다양한 수준의 정확도를 포함하는 특정 국가의 모든 거래 파트너의 데이터가 포함됩니다.
# 필요한 데이터의 양은 두 번째 함정입니다.
# 일부 국가에서는 데이터가 부족하여 소비 기반 회계가 불가능하기 때문입니다.
# 그러나 점점 더 나은 기술이 개발되고 과학계가 최근 출시된 글로벌 데이터베이스(시드니 대학의 EORA, 유럽 컨소시엄의 EXIOPOL 및 WIOD 데이터베이스, 아시아 IDE-JETRO)를 포함한 더 많은 데이터 세트를 생성함에 따라 데이터의 수준과 정확성이 향상될 것입니다.
# 단기적으로는 불확실성 수준을 보다 정확하게 정량화하는 것이 중요할 것입니다.
#
#
# === 국제협력 강화 ===
# 세 번째 문제는 소비 기반 회계가 효과적인 결과를 제공하기 위해 더 큰 국제 협력이 필요하다는 것입니다.
# 정부는 직접적으로 발생하는 배출량에 대해서만 정책을 시행할 권한을 갖습니다.
# 소비 기반 회계에서는 다양한 지정학적 영역의 배출량이 수입국에 할당됩니다.
# 수입국은 수입 습관을 바꾸거나 논의된 바와 같이 국경세를 적용함으로써 이에 간접적으로 반대할 수 있지만, 국제 협력을 통한 더 큰 국제 협력을 통해서만 가능합니다.
# UNFCCC와 같은 단체는 직접적이고 의미 있는 배출 감소를 시행할 수 있습니다.
#
#
# == 배출 책임 공유 ==
# 지금까지 생산기준회계나 소비기준회계 중 하나를 구현해야 한다는 것이 암시되어 왔습니다.
# 그러나 그 대답은 중간 어딘가에 있다는 주장이 있습니다.
# 즉, 수입국과 수출국 간에 배출량을 공유해야 한다는 주장이 있습니다.
# 이 접근 방식은 궁극적으로 생산을 시작하는 사람은 최종 소비자이지만 제품을 생성하는 활동 및 관련 오염도 생산 국가의 GDP에 기여한다고 주장합니다.
# 이 주제는 주로 Rodrigues et al., Lenzen et al., Marques et al.의 연구를 통해 문헌에서 여전히 발전하고 있습니다.
# Andrew와 Forgie와 같은 실증적 연구를 통해서도 마찬가지입니다.
# 결정적으로 공급망의 각 단계에서 관련된 다양한 행위자 간에 사전 정의된 기준에 따라 배출량을 공유할 것을 제안합니다.
# 배출 책임을 공유하는 이러한 접근 방식이 유리한 것처럼 보이지만 사전 정의된 기준이 무엇인지에 대한 논란이 발생합니다.
# 현재 선두 주자 중 두 명은 Lenzen et al.
# "각 에이전트에 할당된 책임 지분은 추가된 가치에 비례해야 한다"고 Rodrigues et al.
# 이들은 "대리인의 소비 기반 책임과 소득 기반 책임 사이의 평균"을 기반으로 해야 한다고 말합니다(Marques et al.에서 인용).
# 기준이 적절하게 개발되지 않았으므로 잠재적으로 가치 있는 개념에 대한 완성된 방법론을 생성하려면 추가 작업이 필요합니다.
#
#
# == 동향 ==
# 지역의 온실가스 배출량 측정은 기후 정책에 매우 중요합니다.
# 현재 정책 결정에 선호되는 방법인 생산 기반 배출 회계가 국제 무역에서 구체화된 배출량을 제외함으로써 온실가스 배출 수준을 상당히 과소평가하고 있다는 것은 분명합니다.
# 이러한 배출량을 포함하는 소비 기반 회계를 구현하면 선진국은 온실가스 배출량에서 더 큰 몫을 차지하므로 결과적으로 개발도상국에 대한 낮은 수준의 배출량 약속은 그다지 중요하지 않습니다.
# 소비 기반 회계는 전 세계 배출량을 포괄할 뿐만 아니라 좋은 환경 행동을 장려하고 경쟁력을 저하시켜 참여를 늘립니다.
# 이러한 장점에도 불구하고 생산 기반 회계에서 소비 기반 회계로의 전환은 틀림없이 한 극단에서 다른 극단으로의 전환을 의미합니다.
# 수입국과 수출국 간 책임을 공유하는 세 번째 옵션은 두 시스템 간의 절충안을 나타냅니다.
# 그러나 아직 이 세 번째 방법에 대해 적절하게 개발된 방법론이 없으므로 정책 결정 결정을 위해 구현되기 전에 추가 연구가 필요합니다.
# 오늘날에는 낮은 불확실성, 확립된 방법론 및 보고, 정치적 경계와 환경 경계 간의 일관성, 광범위한 구현을 고려할 때 선호되는 생산 기반 회계에서 벗어나는 움직임을 보기가 어렵습니다.
# 그러나 국제 무역에 포함된 배출량을 생략한다는 주요 단점 때문에 소비 기반 회계는 귀중한 정보를 제공하며 최소한 생산 기반 회계에 대한 '그림자'로 사용해야 한다는 것이 분명합니다.
# 소비 기반 회계 및 배출 책임 공유 방법론에 대한 추가 작업을 통해 두 가지 모두 미래의 기후 정책에서 더 큰 역할을 할 수 있습니다.
#
#
# == 참조 ==
# 탄소 발자국
# 환경경제학
# 온실가스 모니터링
# 온실가스 관측 위성(GOSAT)(이부키)
#
#
# == 참고자료 ==
#
#
# == 외부링크 ==
# 기후변화에 관한 정부간 패널(IPCC) 국가 온실가스 인벤토리 지침 매뉴얼
# UNFCCC 국가 인벤토리 프로세스
# GHG 프로토콜(WRI/WBCSD) - 기업 회계 및 보고 표준
# 온실가스 회계 및 검증을 위한 ISO 14064 표준
# IPCC 국가 온실가스 인벤토리 프로그램
# 기후 등록부
# 2021년 국가 온실가스 배출 인벤토리(UNFC 수신)
# 2023년에는 CC)
# 온실가스 인벤토리 데이터 – 유연한 쿼리 부속서 I 당사자

# %% [markdown]
# ## 1️⃣ 📊 연도별 총배출량 시계열 분석

# %% [markdown]
# 1-1. 연도별 총배출량 집계

# %%
yearly_total = (
    df_long
    .groupby('연도', as_index=False)['배출량']
    .sum()
    .sort_values('연도')
)

# %%
yearly_total
# Out:
#       연도                                                배출량
# 0   1990  292097.8254424.5240294.5235182.248351.236575.3...
# 1   1991  315341.5281879.1258113.2253554.554790.142684.3...
# 2   1992  343337.6310662.4278995.6275205.962374.95011211...
# 3   1993  378532.9347664.4308499.8305340.368765.156338.8...
# 4   1994  403541.2370444.7327799.7325066.683606.271011.1...
# 5   1995  433757.3402460352000.7349613.291684.7786881236...
# 6   1996  470241.2435519.1385582.1383185.8108977.895316....
# 7   1997  501875.2462376411617.6409141.4122325.2107294.3...
# 8   1998  431387.6383326.7351493.3349141.9106295.2911141...
# 9   1999  469368.6413819.4382112.8379577.1116150.2100604...
# 10  2000  502681.5443704.4411584.7408915.3136124.2120214...
# 11  2001  515955457546425928.7423225.1147477131396.31372...
# 12  2002  538405.9482275445254.6442541.4155764.3140828.4...
# 13  2003  548761.8493177.5452962.6450177.7159992.5144871...
# 14  2004  557011.8500145.3460070.5457010.2172849.3156494...
# 15  2005  561472.1506510.3469372.5466261.4179003.7162906...
# 16  2006  566997.8510828.9474784.8471614.5185847.1170054...
# 17  2007  580340.8523528492405489010.9197249.6181313.113...
# 18  2008  593991.2536386.1506555503103.2210717.6192998.1...
# 19  2009  598001.3540874513041.7509794.8229409212377.714...
# 20  2010  656048.8601295565692.1561911.8254797.3239287.6...
# 21  2011  684703.4631443.4594655.1590614.5262387.6246092...
# 22  2012  688035.3639994.1596004.2591653.6266405.6249479...
# 23  2013  697308.8653919.2604525600054.7272977.1256140.3...
# 24  2014  692100.7647718.7596943.4592851.5258467.4241712...
# 25  2015  692576647012.4600256.4596492.3260499.4242127.8...
# 26  2016  693612.5647071.3602213.7598317262104.3242482.4...
# 27  2017  710743.4668186615604.6611628.1269764.3251381.5...
# 28  2018  727045.2684959632571.9628144.7286398.7268355.6...
# 29  2019  701370.4661820.1611499.1607301.6266224.6248745...

# %% [markdown]
# *국가 온실가스 절대 규모 추세*<br>
# *감축정책 효과, 구조 변화의 1차 지표*

# %% [markdown]
# 6-2. 분야별 구조 변화

# %%
sector_year = (
    df_long
    .groupby(['연도', '분야'], as_index=False)['배출량']
    .sum()
)

# %%
sector_year["분야"].value_counts()
# Out:
# 분야
# A 광물산업                      30
# A 광물산업_1 시멘트생산              30
# C 금속산업_4 마그네슘 생산의 SF6 소비    30
# C 벼재배                       30
# C 벼재배_1 관개                  30
#                             ..
# A 장내발효_5 낙타 및 라마            30
# A 장내발효_6 말                  30
# A 장내발효_7 노새 및 당나귀           30
# A 장내발효_8 돼지                 30
# 폐기물                         30
# Name: count, Length: 144, dtype: int64

# %%
sector_year['비중'] = (
    sector_year['배출량'] /
    sector_year.groupby('연도')['배출량'].transform('sum')
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 3
#       1 sector_year['비중'] = (
#       2     sector_year['배출량'] /
# ----> 3     sector_year.groupby('연도')['배출량'].transform('sum')
#       4 )
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/groupby/generic.py:517, in SeriesGroupBy.transform(self, func, engine, engine_kwargs, *args, **kwargs)
#     514 @Substitution(klass="Series", example=__examples_series_doc)
#     515 @Appender(_transform_template)
#     516 def transform(self, func, *args, engine=None, engine_kwargs=None, **kwargs):
# --> 517     return self._transform(
#     518         func, *args, engine=engine, engine_kwargs=engine_kwargs, **kwargs
#     519     )
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/groupby/groupby.py:2057, in GroupBy._transform(self, func, engine, engine_kwargs, *args, **kwargs)
#    2055             kwargs["engine"] = engine
#    2056             kwargs["engine_kwargs"] = engine_kwargs
# -> 2057         result = getattr(self, func)(*args, **kwargs)
#    2059 return self._wrap_transform_fast_result(result)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/groupby/groupby.py:3153, in GroupBy.sum(self, numeric_only, min_count, engine, engine_kwargs)
#    3148 else:
#    3149     # If we are grouping on categoricals we want unobserved categories to
#    3150     # return zero, rather than the default of NaN which the reindexing in
#    3151     # _agg_general() returns. GH #31422
#    3152     with com.temp_setattr(self, "observed", True):
# -> 3153         result = self._agg_general(
#    3154             numeric_only=numeric_only,
#    3155             min_count=min_count,
#    3156             alias="sum",
#    3157             npfunc=np.sum,
#    3158         )
#    3160     return self._reindex_output(result, fill_value=0, method="sum")
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/groupby/groupby.py:1908, in GroupBy._agg_general(self, numeric_only, min_count, alias, npfunc, **kwargs)
#    1898 @final
#    1899 def _agg_general(
#    1900     self,
#    (...)   1906     **kwargs,
#    1907 ):
# -> 1908     result = self._cython_agg_general(
#    1909         how=alias,
#    1910         alt=npfunc,
#    1911         numeric_only=numeric_only,
#    1912         min_count=min_count,
#    1913         **kwargs,
#    1914     )
#    1915     return result.__finalize__(self.obj, method="groupby")
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/groupby/groupby.py:2005, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    2002     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    2003     return result
# -> 2005 new_mgr = data.grouped_reduce(array_func)
#    2006 res = self._wrap_agged_manager(new_mgr)
#    2007 if how in ["idxmin", "idxmax"]:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/internals/base.py:367, in SingleDataManager.grouped_reduce(self, func)
#     365 def grouped_reduce(self, func):
#     366     arr = self.array
# --> 367     res = func(arr)
#     368     index = default_index(len(res))
#     370     mgr = type(self).from_array(res, index)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/groupby/groupby.py:1980, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1978 def array_func(values: ArrayLike) -> ArrayLike:
#    1979     try:
# -> 1980         result = self._grouper._cython_operation(
#    1981             "aggregate",
#    1982             values,
#    1983             how,
#    1984             axis=data.ndim - 1,
#    1985             min_count=min_count,
#    1986             **kwargs,
#    1987         )
#    1988     except NotImplementedError:
#    1989         # generally if we have numeric_only=False
#    1990         # and non-applicable functions
#    1991         # try to python agg
#    1992         # TODO: shouldn't min_count matter?
#    1993         # TODO: avoid special casing SparseArray here
#    1994         if how in ["any", "all"] and isinstance(values, SparseArray):
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/groupby/ops.py:840, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     838 ids, _, _ = self.group_info
#     839 ngroups = self.ngroups
# --> 840 return cy_op.cython_operation(
#     841     values=values,
#     842     axis=axis,
#     843     min_count=min_count,
#     844     comp_ids=ids,
#     845     ngroups=ngroups,
#     846     **kwargs,
#     847 )
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/groupby/ops.py:559, in WrappedCythonOp.cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     548 if not isinstance(values, np.ndarray):
#     549     # i.e. ExtensionArray
#     550     return values._groupby_op(
#     551         how=self.how,
#     552         has_dropped_na=self.has_dropped_na,
#    (...)    556         **kwargs,
#     557     )
# --> 559 return self._cython_op_ndim_compat(
#     560     values,
#     561     min_count=min_count,
#     562     ngroups=ngroups,
#     563     comp_ids=comp_ids,
#     564     mask=None,
#     565     **kwargs,
#     566 )
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/groupby/ops.py:331, in WrappedCythonOp._cython_op_ndim_compat(self, values, min_count, ngroups, comp_ids, mask, result_mask, initial, **kwargs)
#     329 if result_mask is not None:
#     330     result_mask = result_mask[None, :]
# --> 331 res = self._call_cython_op(
#     332     values2d,
#     333     min_count=min_count,
#     334     ngroups=ngroups,
#     335     comp_ids=comp_ids,
#     336     mask=mask,
#     337     result_mask=result_mask,
#     338     initial=initial,
#     339     **kwargs,
#     340 )
#     341 if res.shape[0] == 1:
#     342     return res[0]
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/groupby/ops.py:427, in WrappedCythonOp._call_cython_op(self, values, min_count, ngroups, comp_ids, mask, result_mask, initial, **kwargs)
#     423     if self.how == "sum":
#     424         # pass in through kwargs only for sum (other functions don't have
#     425         # the keyword)
#     426         kwargs["initial"] = initial
# --> 427     func(
#     428         out=result,
#     429         counts=counts,
#     430         values=values,
#     431         labels=comp_ids,
#     432         min_count=min_count,
#     433         mask=mask,
#     434         result_mask=result_mask,
#     435         is_datetimelike=is_datetimelike,
#     436         **kwargs,
#     437     )
#     438 elif self.how in ["sem", "std", "var", "ohlc", "prod", "median"]:
#     439     if self.how in ["std", "sem"]:
#
# File pandas/_libs/groupby.pyx:732, in pandas._libs.groupby.group_sum()
#
# TypeError: can only concatenate str (not "int") to str

# %%
import numpy as np

df = df_long.copy()

# 원본 문자열
df['raw'] = df['분야 및 연도']

# 앞쪽 공백 개수 → 계층 판단
df['indent'] = df['raw'].str.len() - df['raw'].str.lstrip().str.len()

# 텍스트 정리
df['label'] = df['raw'].str.strip()

df
# Out:
#                              분야 및 연도    연도       배출량  \
# 0                     총배출량(Gg CO2eq)  1990  292097.8
# 1                               순배출량  1990  254424.5
# 2                                에너지  1990  240294.5
# 3                             A 연료연소  1990  235182.2
# 4                     A 연료연소_1 에너지산업  1990   48351.2
# ...                              ...   ...       ...
# 4315                C 국제벙커링 및 다국적 작전  2019  42103.37
# 4316          C 국제벙커링 및 다국적 작전_1 벙커링  2019  42103.37
# 4317  C 국제벙커링 및 다국적 작전_1 벙커링_a 국제 항공  2019  15925.65
# 4318  C 국제벙커링 및 다국적 작전_1 벙커링_b 국제 해운  2019  26177.73
# 4319       C 국제벙커링 및 다국적 작전_2 다국적 작전  2019        C
#
#                                   분야                             raw  indent  \
# 0                     총배출량(Gg CO2eq)                  총배출량(Gg CO2eq)       0
# 1                               순배출량                            순배출량       0
# 2                                에너지                             에너지       0
# 3                             A 연료연소                          A 연료연소       0
# 4                     A 연료연소_1 에너지산업                  A 연료연소_1 에너지산업       0
# ...                              ...                             ...     ...
# 4315                C 국제벙커링 및 다국적 작전                C 국제벙커링 및 다국적 작전       0
# 4316          C 국제벙커링 및 다국적 작전_1 벙커링          C 국제벙커링 및 다국적 작전_1 벙커링       0
# 4317  C 국제벙커링 및 다국적 작전_1 벙커링_a 국제 항공  C 국제벙커링 및 다국적 작전_1 벙커링_a 국제 항공       0
# 4318  C 국제벙커링 및 다국적 작전_1 벙커링_b 국제 해운  C 국제벙커링 및 다국적 작전_1 벙커링_b 국제 해운       0
# 4319       C 국제벙커링 및 다국적 작전_2 다국적 작전       C 국제벙커링 및 다국적 작전_2 다국적 작전       0
#
#                                label
# 0                     총배출량(Gg CO2eq)
# 1                               순배출량
# 2                                에너지
# 3                             A 연료연소
# 4                     A 연료연소_1 에너지산업
# ...                              ...
# 4315                C 국제벙커링 및 다국적 작전
# 4316          C 국제벙커링 및 다국적 작전_1 벙커링
# 4317  C 국제벙커링 및 다국적 작전_1 벙커링_a 국제 항공
# 4318  C 국제벙커링 및 다국적 작전_1 벙커링_b 국제 해운
# 4319       C 국제벙커링 및 다국적 작전_2 다국적 작전
#
# [4320 rows x 7 columns]

# %%
df['대분류'] = np.where(df['indent'] == 0, df['label'], np.nan)
df['대분류'] = df['대분류'].ffill()

df['중분류'] = np.where(df['indent'] > 0, df['label'], np.nan)

df
# Out:
#                              분야 및 연도    연도       배출량  \
# 0                     총배출량(Gg CO2eq)  1990  292097.8
# 1                               순배출량  1990  254424.5
# 2                                에너지  1990  240294.5
# 3                             A 연료연소  1990  235182.2
# 4                     A 연료연소_1 에너지산업  1990   48351.2
# ...                              ...   ...       ...
# 4315                C 국제벙커링 및 다국적 작전  2019  42103.37
# 4316          C 국제벙커링 및 다국적 작전_1 벙커링  2019  42103.37
# 4317  C 국제벙커링 및 다국적 작전_1 벙커링_a 국제 항공  2019  15925.65
# 4318  C 국제벙커링 및 다국적 작전_1 벙커링_b 국제 해운  2019  26177.73
# 4319       C 국제벙커링 및 다국적 작전_2 다국적 작전  2019        C
#
#                                   분야                             raw  indent  \
# 0                     총배출량(Gg CO2eq)                  총배출량(Gg CO2eq)       0
# 1                               순배출량                            순배출량       0
# 2                                에너지                             에너지       0
# 3                             A 연료연소                          A 연료연소       0
# 4                     A 연료연소_1 에너지산업                  A 연료연소_1 에너지산업       0
# ...                              ...                             ...     ...
# 4315                C 국제벙커링 및 다국적 작전                C 국제벙커링 및 다국적 작전       0
# 4316          C 국제벙커링 및 다국적 작전_1 벙커링          C 국제벙커링 및 다국적 작전_1 벙커링       0
# 4317  C 국제벙커링 및 다국적 작전_1 벙커링_a 국제 항공  C 국제벙커링 및 다국적 작전_1 벙커링_a 국제 항공       0
# 4318  C 국제벙커링 및 다국적 작전_1 벙커링_b 국제 해운  C 국제벙커링 및 다국적 작전_1 벙커링_b 국제 해운       0
# 4319       C 국제벙커링 및 다국적 작전_2 다국적 작전       C 국제벙커링 및 다국적 작전_2 다국적 작전       0
#
#                                label                             대분류  중분류
# 0                     총배출량(Gg CO2eq)                  총배출량(Gg CO2eq)  NaN
# 1                               순배출량                            순배출량  NaN
# 2                                에너지                             에너지  NaN
# 3                             A 연료연소                          A 연료연소  NaN
# 4                     A 연료연소_1 에너지산업                  A 연료연소_1 에너지산업  NaN
# ...                              ...                             ...  ...
# 4315                C 국제벙커링 및 다국적 작전                C 국제벙커링 및 다국적 작전  NaN
# 4316          C 국제벙커링 및 다국적 작전_1 벙커링          C 국제벙커링 및 다국적 작전_1 벙커링  NaN
# 4317  C 국제벙커링 및 다국적 작전_1 벙커링_a 국제 항공  C 국제벙커링 및 다국적 작전_1 벙커링_a 국제 항공  NaN
# 4318  C 국제벙커링 및 다국적 작전_1 벙커링_b 국제 해운  C 국제벙커링 및 다국적 작전_1 벙커링_b 국제 해운  NaN
# 4319       C 국제벙커링 및 다국적 작전_2 다국적 작전       C 국제벙커링 및 다국적 작전_2 다국적 작전  NaN
#
# [4320 rows x 9 columns]

# %% [markdown]
# 2-2. 전·후 구간 정의

# %%
df['연도'] = df['연도'].astype(int)

df['시기'] = np.where(
    df['연도'] < 2008, '2008 이전',
    np.where(df['연도'] < 2020, '2008~2019', '2020 이후')
)

# %% [markdown]
# 2-3. 대분류 기준 구조 비교

# %%
policy_compare = (
    df
    .groupby(['시기', '대분류'], as_index=False)['배출량']
    .sum()
)

policy_compare['비중'] = (
    policy_compare['배출량'] /
    policy_compare.groupby('시기')['배출량'].transform('sum')
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[57], line 9
#       1 policy_compare = (
#       2     df
#       3     .groupby(['시기', '대분류'], as_index=False)['배출량']
#       4     .sum()
#       5 )
#       7 policy_compare['비중'] = (
#       8     policy_compare['배출량'] /
# ----> 9     policy_compare.groupby('시기')['배출량'].transform('sum')
#      10 )
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/groupby/generic.py:517, in SeriesGroupBy.transform(self, func, engine, engine_kwargs, *args, **kwargs)
#     514 @Substitution(klass="Series", example=__examples_series_doc)
#     515 @Appender(_transform_template)
#     516 def transform(self, func, *args, engine=None, engine_kwargs=None, **kwargs):
# --> 517     return self._transform(
#     518         func, *args, engine=engine, engine_kwargs=engine_kwargs, **kwargs
#     519     )
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/groupby/groupby.py:2057, in GroupBy._transform(self, func, engine, engine_kwargs, *args, **kwargs)
#    2055             kwargs["engine"] = engine
#    2056             kwargs["engine_kwargs"] = engine_kwargs
# -> 2057         result = getattr(self, func)(*args, **kwargs)
#    2059 return self._wrap_transform_fast_result(result)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/groupby/groupby.py:3153, in GroupBy.sum(self, numeric_only, min_count, engine, engine_kwargs)
#    3148 else:
#    3149     # If we are grouping on categoricals we want unobserved categories to
#    3150     # return zero, rather than the default of NaN which the reindexing in
#    3151     # _agg_general() returns. GH #31422
#    3152     with com.temp_setattr(self, "observed", True):
# -> 3153         result = self._agg_general(
#    3154             numeric_only=numeric_only,
#    3155             min_count=min_count,
#    3156             alias="sum",
#    3157             npfunc=np.sum,
#    3158         )
#    3160     return self._reindex_output(result, fill_value=0, method="sum")
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/groupby/groupby.py:1908, in GroupBy._agg_general(self, numeric_only, min_count, alias, npfunc, **kwargs)
#    1898 @final
#    1899 def _agg_general(
#    1900     self,
#    (...)   1906     **kwargs,
#    1907 ):
# -> 1908     result = self._cython_agg_general(
#    1909         how=alias,
#    1910         alt=npfunc,
#    1911         numeric_only=numeric_only,
#    1912         min_count=min_count,
#    1913         **kwargs,
#    1914     )
#    1915     return result.__finalize__(self.obj, method="groupby")
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/groupby/groupby.py:2005, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    2002     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    2003     return result
# -> 2005 new_mgr = data.grouped_reduce(array_func)
#    2006 res = self._wrap_agged_manager(new_mgr)
#    2007 if how in ["idxmin", "idxmax"]:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/internals/base.py:367, in SingleDataManager.grouped_reduce(self, func)
#     365 def grouped_reduce(self, func):
#     366     arr = self.array
# --> 367     res = func(arr)
#     368     index = default_index(len(res))
#     370     mgr = type(self).from_array(res, index)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/groupby/groupby.py:1980, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1978 def array_func(values: ArrayLike) -> ArrayLike:
#    1979     try:
# -> 1980         result = self._grouper._cython_operation(
#    1981             "aggregate",
#    1982             values,
#    1983             how,
#    1984             axis=data.ndim - 1,
#    1985             min_count=min_count,
#    1986             **kwargs,
#    1987         )
#    1988     except NotImplementedError:
#    1989         # generally if we have numeric_only=False
#    1990         # and non-applicable functions
#    1991         # try to python agg
#    1992         # TODO: shouldn't min_count matter?
#    1993         # TODO: avoid special casing SparseArray here
#    1994         if how in ["any", "all"] and isinstance(values, SparseArray):
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/groupby/ops.py:840, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     838 ids, _, _ = self.group_info
#     839 ngroups = self.ngroups
# --> 840 return cy_op.cython_operation(
#     841     values=values,
#     842     axis=axis,
#     843     min_count=min_count,
#     844     comp_ids=ids,
#     845     ngroups=ngroups,
#     846     **kwargs,
#     847 )
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/groupby/ops.py:559, in WrappedCythonOp.cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     548 if not isinstance(values, np.ndarray):
#     549     # i.e. ExtensionArray
#     550     return values._groupby_op(
#     551         how=self.how,
#     552         has_dropped_na=self.has_dropped_na,
#    (...)    556         **kwargs,
#     557     )
# --> 559 return self._cython_op_ndim_compat(
#     560     values,
#     561     min_count=min_count,
#     562     ngroups=ngroups,
#     563     comp_ids=comp_ids,
#     564     mask=None,
#     565     **kwargs,
#     566 )
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/groupby/ops.py:331, in WrappedCythonOp._cython_op_ndim_compat(self, values, min_count, ngroups, comp_ids, mask, result_mask, initial, **kwargs)
#     329 if result_mask is not None:
#     330     result_mask = result_mask[None, :]
# --> 331 res = self._call_cython_op(
#     332     values2d,
#     333     min_count=min_count,
#     334     ngroups=ngroups,
#     335     comp_ids=comp_ids,
#     336     mask=mask,
#     337     result_mask=result_mask,
#     338     initial=initial,
#     339     **kwargs,
#     340 )
#     341 if res.shape[0] == 1:
#     342     return res[0]
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/groupby/ops.py:427, in WrappedCythonOp._call_cython_op(self, values, min_count, ngroups, comp_ids, mask, result_mask, initial, **kwargs)
#     423     if self.how == "sum":
#     424         # pass in through kwargs only for sum (other functions don't have
#     425         # the keyword)
#     426         kwargs["initial"] = initial
# --> 427     func(
#     428         out=result,
#     429         counts=counts,
#     430         values=values,
#     431         labels=comp_ids,
#     432         min_count=min_count,
#     433         mask=mask,
#     434         result_mask=result_mask,
#     435         is_datetimelike=is_datetimelike,
#     436         **kwargs,
#     437     )
#     438 elif self.how in ["sem", "std", "var", "ohlc", "prod", "median"]:
#     439     if self.how in ["std", "sem"]:
#
# File pandas/_libs/groupby.pyx:732, in pandas._libs.groupby.group_sum()
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# 에러가나서 문자열을 숫자로 강제변환

# %%
df['배출량'] = (
    df['배출량']
    .astype(str)
    .str.replace(',', '', regex=False)
    .str.replace('-', '', regex=False)
    .str.strip()
)

df['배출량'] = pd.to_numeric(df['배출량'], errors='coerce')

# %%
df['배출량'].dtype
# float64 여야 정상
# Out:
# dtype('float64')

# %% [markdown]
# policy코드

# %%
policy_compare = (
    df
    .groupby(['시기', '대분류'], as_index=False)['배출량']
    .sum()
)

policy_compare['비중'] = (
    policy_compare['배출량'] /
    policy_compare.groupby('시기')['배출량'].transform('sum')
)

# %% [markdown]
# ## 연도별 총배출량

# %%
ts = (
    df
    .groupby('연도', as_index=False)['배출량']
    .sum()
    .sort_values('연도')
)

# %% [markdown]
# 시계열 시각화 (추세 확인)

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.plot(ts['연도'], ts['배출량'])
plt.xlabel('Year')
plt.ylabel('Total Emissions')
plt.title('Total Greenhouse Gas Emissions (Time Series)')
plt.show()

# %% [markdown]
# ## 2015 ~ 2020년도 배출량 데이터만 필터링

# %%
mask = (ts['연도'] >= 2015) & (ts['연도'] <= 2020)
ts_2015_2020 = ts.loc[mask]

# %%
ts_2015_2020
# Out:
#       연도         배출량
# 25  2015  4325130.10
# 26  2016  4349253.75
# 27  2017  4440775.18
# 28  2018  4535188.02
# 29  2019  4369041.82

# %% [markdown]
# | 그룹          | 포함 가스           | 특징                |
# | ----------- | --------------- | ----------------- |
# | **CO₂ 계열**  | CO₂             | 배출량 최대, 구조적 감축 핵심 |
# | **CH₄ 계열**  | CH₄             | 단기 고위험, 농업·폐기물    |
# | **N₂O 계열**  | N₂O             | 농업 기원, 고 GWP      |
# | **F-gases** | HFCs, PFCs, SF₆ | 소량·초고위험           |

# %% [markdown]
# ## 해당 기간 평균 배출량 계산

# %%
avg_2015_2020 = ts_2015_2020['배출량'].mean()
avg_2015_2020
print(f"2015~2020년 평균 배출량:{avg_2015_2020:,.0f}")
# Out:
# 2015~2020년 평균 배출량:4,403,878

# %% [markdown]
# _2015년~2020년까지의 평균 온실가스 배출량은 약 440만 톤 수준으로 나타남_

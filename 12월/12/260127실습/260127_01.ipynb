# %% [markdown]
# # 패키지 로드 및 데이터불러오기

# %%
# -------------------------------
# 사용자 정의 모듈
# -------------------------------
from hossam import load_data, my_dpi, visualize_silhouette


# -------------------------------
# 데이터 처리
# -------------------------------
import numpy as np
from pandas import DataFrame
from matplotlib import pyplot as plt
import seaborn as sb

# -------------------------------
# 시각화
# -------------------------------
import seaborn as sb
from matplotlib import pyplot as plt


# -------------------------------
# 머신러닝 / 평가 지표
# -------------------------------
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score, silhouette_samples
from sklearn.cluster import AgglomerativeClustering
from sklearn.decomposition import PCA

# -------------------------------
# 기하 / 계층적 군집
# -------------------------------
from scipy.spatial import ConvexHull
from scipy.cluster.hierarchy import dendrogram, linkage

# %%
origin=load_data("wine_qt")
# Out:
# 이 데이터셋은 와인의 화학적·물리적 특성을 나타내는 연속형 변수들과, 이를 종합해 평가한 품질 점수(quality)로 구성되어 있습니다. (출처: https://www.kaggle.com/datasets/yasserh/wine-quality-dataset)
#
# 변수                  설명
# --------------------  ----------------
# fixed acidity         고정 산도
# volatile acidity      휘발성 산도
# citric acid           구연산
# residual sugar        잔당
# chlorides             염화물
# free sulfur dioxide   유리 아황산
# total sulfur dioxide  총 아황산
# density               밀도
# pH                    산성도
# sulphates             황산염
# alcohol               알코올 도수
# quality               품질 점수 (0~10)

# %% [markdown]
# ### 종속변수 제거

# %%
df1=origin.drop("quality",axis=1)
df1.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol
# 0      9.4
# 1      9.8
# 2      9.8
# 3      9.8
# 4      9.4

# %% [markdown]
# ### 스케일링

# %%
scaler=StandardScaler()
sdf=DataFrame(scaler.fit_transform(df1),columns=df1.columns)
sdf.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0      -0.521580          0.939332    -1.365027       -0.466421  -0.231395
# 1      -0.292593          1.941813    -1.365027        0.050060   0.234247
# 2      -0.292593          1.273492    -1.161568       -0.171289   0.107253
# 3       1.653789         -1.399789     1.483400       -0.466421  -0.252560
# 4      -0.521580          0.939332    -1.365027       -0.466421  -0.231395
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0            -0.450467             -0.363610  0.555854  1.270695  -0.573658
# 1             0.915920              0.643477  0.036165 -0.708928   0.130881
# 2            -0.060071              0.246745  0.140103 -0.325775  -0.045254
# 3             0.135127              0.429852  0.659792 -0.964363  -0.456235
# 4            -0.450467             -0.363610  0.555854  1.270695  -0.573658
#
#     alcohol
# 0 -0.963382
# 1 -0.593601
# 2 -0.593601
# 3 -0.593601
# 4 -0.963382

# %% [markdown]
# # 차원축소

# %% [markdown]
# ### 차원축소 실행

# %%
from sklearn.decomposition import PCA
estimator=PCA(n_components="mle",random_state=52)
pca=estimator.fit_transform(sdf)
pca
# Out:
# array([[-1.56154478,  0.44489171, -1.76720916, ...,  0.33008582,
#         -0.01154807, -0.24961113],
#        [-0.76089236,  1.91505819, -0.8641578 , ..., -0.74693875,
#          0.54764364,  0.00519571],
#        [-0.70808539,  0.91442316, -1.14236292, ..., -0.57565201,
#          0.08411791, -0.20371481],
#        ...,
#        [-2.12463519,  0.87380431,  0.62657264, ...,  0.35760108,
#          1.00809106,  0.29669087],
#        [-2.20853569,  0.92834262,  1.815403  , ...,  0.26946144,
#          1.15057722,  0.43650587],
#        [-2.24173343,  1.00318928,  0.65088927, ...,  0.49897478,
#          0.70794013,  0.74328967]], shape=(1143, 10))

# %% [markdown]
# ### 데이터프레임으로 구성

# %%
n=pca.shape[1]
cols=[f"PC{i+1}"for i in range(n)]

pca_df=DataFrame(pca,columns=cols)
pca_df["target"]=origin["quality"]

pca_df
# Out:
#            PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0    -1.561545  0.444892 -1.767209  0.132635  0.130138  0.906815  0.122336
# 1    -0.760892  1.915058 -0.864158  0.536890  0.090935 -0.860406  0.998623
# 2    -0.708085  0.914423 -1.142363  0.435075  0.024940 -0.356702  0.536162
# 3     2.308166 -0.224448  0.256895 -0.830630 -1.639209  0.154720 -0.300410
# 4    -1.561545  0.444892 -1.767209  0.132635  0.130138  0.906815  0.122336
# ...        ...       ...       ...       ...       ...       ...       ...
# 1138 -1.442233  0.332152  1.137812  0.441063  0.232027  0.499123  0.185077
# 1139 -1.222998  0.921618  0.027234  0.855285 -0.155510  1.130942  0.605893
# 1140 -2.124635  0.873804  0.626573  0.399466 -0.177268 -0.063081 -0.221032
# 1141 -2.208536  0.928343  1.815403  0.339723  0.189002  0.665644  0.539637
# 1142 -2.241733  1.003189  0.650889  0.637998  0.164616  0.831190  0.272703
#
#            PC8       PC9      PC10  target
# 0     0.330086 -0.011548 -0.249611       5
# 1    -0.746939  0.547644  0.005196       5
# 2    -0.575652  0.084118 -0.203715       5
# 3     0.494589 -0.110087 -0.121798       6
# 4     0.330086 -0.011548 -0.249611       5
# ...        ...       ...       ...     ...
# 1138 -0.061655  0.867211  0.217315       6
# 1139 -0.364230  0.868018  0.581082       6
# 1140  0.357601  1.008091  0.296691       5
# 1141  0.269461  1.150577  0.436506       6
# 1142  0.498975  0.707940  0.743290       5
#
# [1143 rows x 11 columns]

# %% [markdown]
# # 결과해석

# %% [markdown]
# ### 주성분별 설명력

# %%
estimator.explained_variance_ratio_
# Out:
# array([0.28692345, 0.17075104, 0.14305928, 0.1101368 , 0.08711032,
#        0.06048811, 0.05069067, 0.03809625, 0.03131763, 0.01611195])

# %% [markdown]
# ### 누적 설명력

# %%
estimator.explained_variance_ratio_.cumsum()
# Out:
# array([0.28692345, 0.45767448, 0.60073377, 0.71087056, 0.79798089,
#        0.85846899, 0.90915967, 0.94725592, 0.97857355, 0.9946855 ])

# %% [markdown]
# 누적 설명력이 80% 초과되는 지점까지만 주성분 생성

# %%
estimator = PCA(n_components = 0.8, random_state=52)
pca = estimator.fit_transform(sdf)

n=pca.shape[1]
cols=[f"PC:{i+1}" for i in range(n)]

pca_df = DataFrame(pca,columns=cols)
pca_df["target"] = origin["quality"]
pca_df
# Out:
#           PC:1      PC:2      PC:3      PC:4      PC:5      PC:6  target
# 0    -1.561545  0.444892 -1.767209  0.132635  0.130138  0.906815       5
# 1    -0.760892  1.915058 -0.864158  0.536890  0.090935 -0.860406       5
# 2    -0.708085  0.914423 -1.142363  0.435075  0.024940 -0.356702       5
# 3     2.308166 -0.224448  0.256895 -0.830630 -1.639209  0.154720       6
# 4    -1.561545  0.444892 -1.767209  0.132635  0.130138  0.906815       5
# ...        ...       ...       ...       ...       ...       ...     ...
# 1138 -1.442233  0.332152  1.137812  0.441063  0.232027  0.499123       6
# 1139 -1.222998  0.921618  0.027234  0.855285 -0.155510  1.130942       6
# 1140 -2.124635  0.873804  0.626573  0.399466 -0.177268 -0.063081       5
# 1141 -2.208536  0.928343  1.815403  0.339723  0.189002  0.665644       6
# 1142 -2.241733  1.003189  0.650889  0.637998  0.164616  0.831190       5
#
# [1143 rows x 7 columns]

# %% [markdown]
# ### 주성분 로딩 벡터

# %%
estimator.components_
# Out:
# array([[ 0.48533856, -0.22714317,  0.46007532,  0.17450629,  0.22487011,
#         -0.04785179,  0.01506861,  0.39968417, -0.43284424,  0.23755529,
#         -0.11879903],
#        [-0.10232799,  0.28878641, -0.14650773,  0.2522617 ,  0.15313338,
#          0.51702178,  0.57739283,  0.21753697, -0.00637351, -0.06228016,
#         -0.38163504],
#        [-0.12237612, -0.44371805,  0.24684311,  0.09135939, -0.05256247,
#          0.42828836,  0.32342387, -0.33423846,  0.05992279,  0.30276801,
#          0.47020106],
#        [-0.23604559,  0.07728789, -0.06381775, -0.40726337,  0.65266911,
#         -0.05080877, -0.0466689 , -0.16401907, -0.00672433,  0.52754686,
#         -0.17995347],
#        [-0.09737837,  0.25755756, -0.07767357,  0.70114127,  0.27064882,
#         -0.14928186, -0.21047961,  0.15154184,  0.28885414,  0.25049523,
#          0.34287354],
#        [-0.10336891, -0.41609139, -0.08936147, -0.02481684, -0.31893577,
#          0.00952849, -0.09487849,  0.4017928 ,  0.50678678,  0.37739484,
#         -0.3688788 ]])

# %% [markdown]
# ### 시각화

# %%
# # -------------------------------
# # 축 이름 설정
# # -------------------------------
# xname = "PC1"
# yname = "PC2"


# # -------------------------------
# # 필요한 정보 추출
# # -------------------------------
# score = estimator.transform(sdf)
# components = estimator.components_

# x_index = pca_df.columns.get_loc(xname)
# y_index = pca_df.columns.get_loc(yname)

# xs = score[:, x_index]
# ys = score[:, y_index]
# n = score.shape[1]

# scale_x = 1.0 / (xs.max() - xs.min())
# scale_y = 1.0 / (ys.max() - ys.min())


# # -------------------------------
# # 시각화
# # -------------------------------
# figsize = (1280 / my_dpi, 720 / my_dpi)
# fig, ax = plt.subplots(
#     nrows=1,
#     ncols=1,
#     figsize=figsize,
#     dpi=my_dpi
# )

# sb.scatterplot(
#     x=xs * scale_x,
#     y=ys * scale_y,
#     hue=pca_df["target"],
#     palette="Set1",
#     ax=ax,
#     alpha=0.7
# )


# # -------------------------------
# # 변수 로딩 벡터 표시
# # -------------------------------
# for i in range(n):

#     ax.arrow(
#         0,
#         0,
#         components[x_index, i],
#         components[y_index, i],
#         color="r",
#         alpha=0.5,
#         head_width=0.02,
#         head_length=0.02,
#     )

#     ax.text(
#         components[x_index, i] * 1.15,
#         components[y_index, i] * 1.15,
#         f"{df1.columns[i]} ({components[x_index, i]:.2f})",
#         color="b",
#         ha="center",
#         va="center",
#     )


# # -------------------------------
# # 그래프 옵션 및 출력
# # -------------------------------
# ax.grid(True, alpha=0.3)
# ax.set_xlabel(xname)
# ax.set_ylabel(yname)

# plt.tight_layout()
# plt.show()
# plt.close()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\itwill\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'PC1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 14
#      11 score = estimator.transform(sdf)
#      12 components = estimator.components_
# ---> 14 x_index = pca_df.columns.get_loc(xname)
#      15 y_index = pca_df.columns.get_loc(yname)
#      17 xs = score[:, x_index]
#
# File c:\Users\itwill\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'PC1'

# %%
def make_pca_df(X, n_components=2):
    pca = PCA(n_components=n_components)
    score = pca.fit_transform(X)
    cols = [f"PC{i+1}" for i in range(n_components)]
    return pd.DataFrame(score, columns=cols), pca
print(pca)
# Out:
# [[-1.56154478  0.44489171 -1.76720916  0.13263477  0.13013821  0.90681489]
#  [-0.76089236  1.91505819 -0.8641578   0.53688953  0.09093505 -0.86040617]
#  [-0.70808539  0.91442316 -1.14236292  0.43507543  0.02493984 -0.3567019 ]
#  ...
#  [-2.12463519  0.87380431  0.62657264  0.39946622 -0.17726769 -0.0630808 ]
#  [-2.20853569  0.92834262  1.815403    0.33972263  0.18900173  0.66564411]
#  [-2.24173343  1.00318928  0.65088927  0.63799776  0.16461573  0.83118991]]

# %%
# PC1, PC2는 항상 0, 1
x_index = 0
y_index = 1

xs = score[:, x_index]
ys = score[:, y_index]
n = components.shape[1]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 5))
sns.scatterplot(
    data=result_df,
    x="PC1",
    y="PC2",
    hue="cluster",
    palette="Set2"
)
plt.title("PCA + Clustering Result")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 6
#       2 import matplotlib.pyplot as plt
#       4 plt.figure(figsize=(6, 5))
#       5 sns.scatterplot(
# ----> 6     data=result_df,
#       7     x="PC1",
#       8     y="PC2",
#       9     hue="cluster",
#      10     palette="Set2"
#      11 )
#      12 plt.title("PCA + Clustering Result")
#      13 plt.show()
#
# NameError: name 'result_df' is not defined

# %%
from sklearn.cluster import AgglomerativeClustering

cluster = AgglomerativeClustering(n_clusters=3)
labels = cluster.fit_predict(pca_df)

result_df = df.copy()
result_df1["PC1"] = pca_df["PC1"]
result_df1["PC2"] = pca_df["PC2"]
result_df1["cluster"] = labels

result_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[54], line 6
#       3 cluster = AgglomerativeClustering(n_clusters=3)
#       4 labels = cluster.fit_predict(pca_df)
# ----> 6 result_df = df.copy()
#       7 result_df1["PC1"] = pca_df["PC1"]
#       8 result_df1["PC2"] = pca_df["PC2"]
#
# NameError: name 'df' is not defined

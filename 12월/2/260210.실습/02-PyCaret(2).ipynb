# %% [markdown]
# # [LAB99] AutoML > 02-PyCaret(2)

# %% [markdown]
# ## #01. 준비작업
#
# ### [1] 패키지 참조
#
# 초기 로딩시간이 오래 걸린다.

# %%
from hossam import *
from pandas import concat
from pycaret.regression import *
# Out:
# 📦 아이티윌 이광호 강사가 제작한 라이브러리를 사용중입니다.
# 📚 자세한 사용 방법은 https://py.hossam.kr 을 참고하세요.
# 📧 Email: leekh4232@gmail.com
# 🎬 Youtube: https://www.youtube.com/@hossam-codingclub
# 📝 Blog: https://blog.hossam.kr/
# 🔖 Version: 0.5.3
#
# ✅ 시각화를 위한 한글 글꼴(NotoSansKR-Regular)이 자동 적용되었습니다.

# %% [markdown]
# ### [2] 데이터 불러오기 + 인덱스 설정 + 카테고리 타입 지정

# %%
origin = load_data("restaurant_sales_preprocessed")
origin.set_index("date", inplace=True)
origin["holiday"] = origin["holiday"].astype("category")
origin["weekend"] = origin["weekend"].astype("category")
origin.info()
# Out:
# 어느 식당의 1년간 일별 매출을 기록한 데이터의 전처리 완료 버전(명목형이 이진변수만 있으므로 더미변수는 처리하지 않음)
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 353 entries, 2024-01-01 to 2024-12-30
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sales           353 non-null    float64
#  1   visitors        353 non-null    int64
#  2   avg_price       353 non-null    int64
#  3   marketing_cost  353 non-null    float64
#  4   delivery_ratio  353 non-null    float64
#  5   rain_mm         353 non-null    float64
#  6   temperature     353 non-null    float64
#  7   holiday         353 non-null    category
#  8   weekend         353 non-null    category
# dtypes: category(2), float64(5), int64(2)
# memory usage: 23.0 KB

# %% [markdown]
# ## #02. PyCaret setup

# %%
s = RegressionExperiment()

s.setup(
    #-------------------------------------
    # 기본 설정 (필수 지정)
    #-------------------------------------
    # 데이터셋 지정
    data=origin,
    # 예측 목표 변수 지정
    target="sales",
    # 랜덤 시드 고정
    session_id=52,
    # 훈련 데이터 비율 (기본값=0.7)
    train_size=0.75,
    # 교차검증 폴드 수 지정
    fold=5,
    # 처리과정 출력 안함 (기본값 True, False 권장. 출력 과정이 다소 길어질 수 있음)
    verbose=False,
    # GPU 사용 여부 지정 (기본값 False) - True로 설정하면 컴퓨터 환경에 따라 지원 안될 경우 에러 발생
    use_gpu=False,
    #-------------------------------------
    # 전처리 설정 (1)
    #-------------------------------------
    # 범주형 변수 지정(기본값 None)
    categorical_features=['weekend', 'holiday'],
    # 생략할 변수 지정(기본값 None)
    ignore_features=[],
    # 데이터 정규화/표준화 활성화(기본값 False)
    normalize=True,
    # 데이터 정규화/표준화 방법 선택 (zscore가 StandardScaler와 동일)
    # 'minmax', 'maxabs', 'robust', 'zscore'
    normalize_method='zscore',
    #-------------------------------------
    # 전처리 설정 (2) - 아래 기능은 사용하지 말고, 데이터 별도의 전처리 단계를 거치는 것을 권장
    #-------------------------------------
    # 이상치 제거 (기본값 False, IQR 범위 밖의 값을 삭제함)
    remove_outliers=False,
    # 이상치 제거 임계값 (기본값 0.05, 상하위 몇 %를 이상치로 간주할지 지정)
    outliers_threshold=0.05,
    # 종속변수 변환 (기본값 False)
    transform_target=False,
    # 변수 선택 (기본값 False)
    feature_selection=False
)

# %%
s.pull()
# Out:
#                     Description             Value
# 0                    Session id                52
# 1                        Target             sales
# 2                   Target type        Regression
# 3           Original data shape          (353, 9)
# 4        Transformed data shape          (353, 9)
# 5   Transformed train set shape          (264, 9)
# 6    Transformed test set shape           (89, 9)
# 7              Numeric features                 6
# 8          Categorical features                 2
# 9                    Preprocess              True
# 10              Imputation type            simple
# 11           Numeric imputation              mean
# 12       Categorical imputation              mode
# 13     Maximum one-hot encoding                25
# 14              Encoding method              None
# 15                    Normalize              True
# 16             Normalize method            zscore
# 17               Fold Generator             KFold
# 18                  Fold Number                 5
# 19                     CPU Jobs                -1
# 20                      Use GPU             False
# 21               Log Experiment             False
# 22              Experiment Name  reg-default-name
# 23                          USI              1f5f

# %% [markdown]
# ## #03. 베이스 모델 구축하기
#
# ### [1] 사용할 수 있는 학습 모델의 종류 확인

# %%
s.models()
# Out:
#                                        Name  \
# ID
# lr                        Linear Regression
# lasso                      Lasso Regression
# ridge                      Ridge Regression
# en                              Elastic Net
# lar                  Least Angle Regression
# llar           Lasso Least Angle Regression
# omp             Orthogonal Matching Pursuit
# br                           Bayesian Ridge
# ard       Automatic Relevance Determination
# par            Passive Aggressive Regressor
# ransac              Random Sample Consensus
# tr                       TheilSen Regressor
# huber                       Huber Regressor
# kr                             Kernel Ridge
# svm               Support Vector Regression
# knn                   K Neighbors Regressor
# dt                  Decision Tree Regressor
# rf                  Random Forest Regressor
# et                    Extra Trees Regressor
# ada                      AdaBoost Regressor
# gbr             Gradient Boosting Regressor
# mlp                           MLP Regressor
# xgboost           Extreme Gradient Boosting
# lightgbm    Light Gradient Boosting Machine
# catboost                 CatBoost Regressor
# dummy                       Dummy Regressor
#
#                                                                     Reference  \
# ID
# lr                                sklearn.linear_model._base.LinearRegression
# lasso                          sklearn.linear_model._coordinate_descent.Lasso
# ridge                                       sklearn.linear_model._ridge.Ridge
# en                        sklearn.linear_model._coordinate_descent.ElasticNet
# lar                                    sklearn.linear_model._least_angle.Lars
# llar                              sklearn.linear_model._least_angle.LassoLars
# omp                       sklearn.linear_model._omp.OrthogonalMatchingPursuit
# br                                  sklearn.linear_model._bayes.BayesianRidge
# ard                                 sklearn.linear_model._bayes.ARDRegression
# par       sklearn.linear_model._passive_aggressive.PassiveAggressiveRegressor
# ransac                           sklearn.linear_model._ransac.RANSACRegressor
# tr                          sklearn.linear_model._theil_sen.TheilSenRegressor
# huber                              sklearn.linear_model._huber.HuberRegressor
# kr                                           sklearn.kernel_ridge.KernelRidge
# svm                                                  sklearn.svm._classes.SVR
# knn                         sklearn.neighbors._regression.KNeighborsRegressor
# dt                                sklearn.tree._classes.DecisionTreeRegressor
# rf                             sklearn.ensemble._forest.RandomForestRegressor
# et                               sklearn.ensemble._forest.ExtraTreesRegressor
# ada                       sklearn.ensemble._weight_boosting.AdaBoostRegressor
# gbr                            sklearn.ensemble._gb.GradientBoostingRegressor
# mlp                sklearn.neural_network._multilayer_perceptron.MLPRegressor
# xgboost                                          xgboost.sklearn.XGBRegressor
# lightgbm                                       lightgbm.sklearn.LGBMRegressor
# catboost                                      catboost.core.CatBoostRegressor
# dummy                                            sklearn.dummy.DummyRegressor
#
#           Turbo
# ID
# lr         True
# lasso      True
# ridge      True
# en         True
# lar        True
# llar       True
# omp        True
# br         True
# ard       False
# par        True
# ransac    False
# tr        False
# huber      True
# kr        False
# svm       False
# knn        True
# dt         True
# rf         True
# et         True
# ada        True
# gbr        True
# mlp       False
# xgboost    True
# lightgbm   True
# catboost   True
# dummy      True

# %% [markdown]
# ### [2] 베이스 모델 성능 비교
#
# #### 모든 모델에 대한 성능 비교

row3_col7" class="data row3 col7" >0.0100</td>
#     </tr>
#     <tr>
#       <th id="T_38118_level0_row4" class="row_heading level0 row4" >huber</th>
#       <td id="T_38118_row4_col0" class="data row4 col0" >Huber Regressor</td>
#       <td id="T_38118_row4_col1" class="data row4 col1" >0.1653</td>
#       <td id="T_38118_row4_col2" class="data row4 col2" >0.0429</td>
#       <td id="T_38118_row4_col3" class="data row4 col3" >0.2062</td>
#       <td id="T_38118_row4_col4" class="data row4 col4" >0.6938</td>
#       <td id="T_38118_row4_col5" class="data row4 col5" >0.0119</td>
#       <td id="T_38118_row4_col6" class="data row4 col6" >0.0101</td>
#       <td id="T_38118_row4_col7" class="data row4 col7" >0.0100</td>
#     </tr>
#     <tr>
#       <th id="T_38118_level0_row5" class="row_heading level0 row5" >rf</th>
#       <td id="T_38118_row5_col0" class="data row5 col0" >Random Forest Regressor</td>
#       <td id="T_38118_row5_col1" class="data row5 col1" >0.1751</td>
#       <td id="T_38118_row5_col2" class="data row5 col2" >0.0494</td>
#       <td id="T_38118_row5_col3" class="data row5 col3" >0.2214</td>
#       <td id="T_38118_row5
# [BayesianRidge(),
#  Ridge(random_state=52),
#  LinearRegression(n_jobs=-1),
#  Lars(random_state=52),
#  HuberRegressor()]

# %% [markdown]
# #### 주요 모델만 선정하여 성능 비교
#
# 수업에서 사용한 모델만을 대상으로 베이스모델간의 성능비교

# %%
best5models = s.compare_models(include=["lr", "ridge", "lasso", "en", "knn", "svm", "dt", "xgboost", "lightgbm", "catboost"], sort='RMSE', n_select=5, fold=5)
best5models
# Out:
# <style type="text/css">
# #T_664b0 th {
#   text-align: left;
# }
# #T_664b0_row0_col0, #T_664b0_row1_col0, #T_664b0_row1_col1, #T_664b0_row1_col2, #T_664b0_row1_col3, #T_664b0_row1_col4, #T_664b0_row2_col0, #T_664b0_row2_col1, #T_664b0_row2_col2, #T_664b0_row2_col3, #T_664b0_row2_col4, #T_664b0_row2_col5, #T_664b0_row2_col6, #T_664b0_row3_col0, #T_664b0_row3_col1, #T_664b0_row3_col2, #T_664b0_row3_col3, #T_664b0_row3_col4, #T_664b0_row3_col5, #T_664b0_row3_col6, #T_664b0_row4_col0, #T_664b0_row4_col1, #T_664b0_row4_col2, #T_664b0_row4_col3, #T_664b0_row4_col4, #T_664b0_row4_col5, #T_664b0_row4_col6, #T_664b0_row5_col0, #T_664b0_row5_col1, #T_664b0_row5_col2, #T_664b0_row5_col3, #T_664b0_row5_col4, #T_664b0_row5_col5, #T_664b0_row5_col6, #T_664b0_row6_col0, #T_664b0_row6_col1, #T_664b0_row6_col2, #T_664b0_row6_col3, #T_664b0_row6_col4, #T_664b0_row6_col5, #T_664b0_row6_col6, #T_664b0_row7_col0, #T_664b0_row7_col1, #T_664b0_row7_col2, #T_664b0_row7_col3, #T_664b0_row7_col4, #T_664b0_row7_col5, #T_664b0_row7_col6, #T_664b0_row8_col0, #T_664b0_row8_col1, #T_664b0_row8_col2, #T_664b0_row8_col3, #T_664b0_row8_col4, #T_664b0_row8_col5, #T_664b0_row8_col6, #T_664b0_row9_col0, #T_664b0_row9_col1, #T_664b0_row9_col2, #T_664b0_row9_col3, #T_664b0_row9_col4, #T_664b0_row9_col5, #T_664b0_row9_col6 {
#   text-align: left;
# }
# #T_664b0_row0_col1, #T_664b0_row0_col2, #T_664b0_row0_col3, #T_664b0_row0_col4, #T_664b0_row0_col5, #T_664b0_row0_col6, #T_664b0_row1_col5, #T_664b0_row1_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_664b0_row0_col7, #T_664b0_row1_col7, #T_664b0_row2_col7, #T_664b0_row3_col7, #T_664b0_row4_col7, #T_664b0_row5_col7, #T_664b0_row6_col7, #T_664b0_row7_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_664b0_row8_col7, #T_664b0_row9_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_664b0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_664b0_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_664b0_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_664b0_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_664b0_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_664b0_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_664b0_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_664b0_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_664b0_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_664b0_level0_row0" class="row_heading level0 row0" >ridge</th>
#       <td id="T_664b0_row0_col0" class="data row0 col0" >Ridge Regression</td>
#       <td id="T_664b0_row0_col1" class="data row0 col1" >0.1657</td>
#       <td id="T_664b0_row0_col2" class="data row0 col2" >0.0428</td>
#       <td id="T_664b0_row0_col3" class="data row0 col3" >0.2060</td>
#       <td id="T_664b0_row0_col4" class="data row0 col4" >0.6948</td>
#       <td id="T_664b0_row0_col5" class="data row0 col5" >0.0119</td>
#       <td id="T_664b0_row0_col6" class="data row0 col6" >0.0101</td>
#       <td id="T_664b0_row0_col7" class="data row0 col7" >0.0080</td>
#     </tr>
#     <tr>
#       <th id="T_664b0_level0_row1" class="row_heading level0 row1" >lr</th>
#       <td id="T_664b0_row1_col0" class="data row1 col0" >Linear Regression</td>
#       <td id="T_664b0_row1_col1" class="data row1 col1" >0.1658</td>
#       <td id="T_664b0_row1_col2" class="data row1 col2" >0.0429</td>
#       <td id="T_664b0_row1_col3" class="data row1 col3" >0.2061</td>
#       <td id="T_664b0_row1_col4" class="data row1 col4" >0.6943</td>
#       <td id="T_664b0_row1_col5" class="data row1 col5" >0.0119</td>
#       <td id="T_664b0_row1_col6" class="data row1 col6" >0.0101</td>
#       <td id="T_664b0_row1_col7" class="data row1 col7" >0.0080</td>
#     </tr>
#     <tr>
#       <th id="T_664b0_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_664b0_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_664b0_row2_col1" class="data row2 col1" >0.1799</td>
#       <td id="T_664b0_row2_col2" class="data row2 col2" >0.0517</td>
#       <td id="T_664b0_row2_col3" class="data row2 col3" >0.2256</td>
#       <td id="T_664b0_row2_col4" class="data row2 col4" >0.6329</td>
#       <td id="T_664b0_row2_col5" class="data row2 col5" >0.0130</td>
#       <td id="T_664b0_row2_col6" class="data row2 col6" >0.0110</td>
#       <td id="T_664b0_row2_col7" class="data row2 col7" >0.0720</td>
#     </tr>
#     <tr>
#       <th id="T_664b0_level0_row3" class="row_heading level0 row3" >svm</th>
#       <td id="T_664b0_row3_col0" class="data row3 col0" >Support Vector Regression</td>
#       <td id="T_664b0_row3_col1" class="data row3 col1" >0.1811</td>
#       <td id="T_664b0_row3_col2" class="data row3 col2" >0.0526</td>
#       <td id="T_664b0_row3_col3" class="data row3 col3" >0.2284</td>
#       <td id="T_664b0_row3_col4" class="data row3 col4" >0.6323</td>
#       <td id="T_664b0_row3_col5" class="data row3 col5" >0.0131</td>
#       <td id="T_664b0_row3_col6" class="data row3 col6" >0.0111</td>
#       <td id="T_664b0_row3_col7" class="data row3 col7" >0.0080</td>
#     </tr>
#     <tr>
#       <th id="T_664b0_level0_row4" class="row_heading level0 row4" >catboost</th>
#       <td id="T_664b0_row4_col0" class="data row4 col0" >CatBoost Regressor</td>
#       <td id="T_664b0_row4_col1" class="data row4 col1" >0.1851</td>
#       <td id="T_664b0_row4_col2" class="data row4 col2" >0.0534</td>
#       <td id="T_664b0_row4_col3" class="data row4 col3" >0.2299</td>
#       <td id="T_664b0_row4_col4" class="data row4 col4" >0.6235</td>
#       <td id="T_664b0_row4_col5" class="data row4 col5" >0.0132</td>
#       <td id="T_664b0_row4_col6" class="data row4 col6" >0.0113</td>
#       <td id="T_664b0_row4_col7" class="data row4 col7" >0.1260</td>
#     </tr>
#     <tr>
#       <th id="T_664b0_level0_row5" class="row_heading level0 row5" >xgboost</th>
#       <td id="T_664b0_row5_col0" class="data row5 col0" >Extreme Gradient Boosting</td>
#       <td id="T_664b0_row5_col1" class="data row5 col1" >0.1884</td>
#       <td id="T_664b0_row5_col2" class="data row5 col2" >0.0552</td>
#       <td id="T_664b0_row5_col3" class="data row5 col3" >0.2344</td>
#       <td id="T_664b0_row5_col4" class="data row5 col4" >0.6114</td>
#       <td id="T_664b0_row5_col5" class="data row5 col5" >0.0135</td>
#       <td id="T_664b0_row5_col6" class="data row5 col6" >0.0115</td>
#       <td id="T_664b0_row5_col7" class="data row5 col7" >0.0120</td>
#     </tr>
#     <tr>
#       <th id="T_664b0_level0_row6" class="row_heading level0 row6" >knn</th>
#       <td id="T_664b0_row6_col0" class="data row6 col0" >K Neighbors Regressor</td>
#       <td id="T_664b0_row6_col1" class="data row6 col1" >0.1878</td>
#       <td id="T_664b0_row6_col2" class="data row6 col2" >0.0558</td>
#       <td id="T_664b0_row6_col3" class="data row6 col3" >0.2358</td>
#       <td id="T_664b0_row6_col4" class="data row6 col4" >0.6041</td>
#       <td id="T_664b0_row6_col5" class="data row6 col5" >0.0136</td>
#       <td id="T_664b0_row6_col6" class="data row6 col6" >0.0115</td>
#       <td id="T_664b0_row6_col7" class="data row6 col7" >0.0100</td>
#     </tr>
#     <tr>
#       <th id="T_664b0_level0_row7" class="row_heading level0 row7" >dt</th>
#       <td id="T_664b0_row7_col0" class="data row7 col0" >Decision Tree Regressor</td>
#       <td id="T_664b0_row7_col1" class="data row7 col1" >0.2458</td>
#       <td id="T_664b0_row7_col2" class="data row7 col2" >0.0994</td>
#       <td id="T_664b0_row7_col3" class="data row7 col3" >0.3135</td>
#       <td id="T_664b0_row7_col4" class="data row7 col4" >0.2846</td>
#       <td id="T_664b0_row7_col5" class="data row7 col5" >0.0181</td>
#       <td id="T_664b0_row7_col6" class="data row7 col6" >0.0150</td>
#       <td id="T_664b0_row7_col7" class="data row7 col7" >0.0080</td>
#     </tr>
#     <tr>
#       <th id="T_664b0_level0_row8" class="row
# [Ridge(random_state=52),
#  LinearRegression(n_jobs=-1),
#  LGBMRegressor(n_jobs=-1, random_state=52),
#  SVR(),
#  <catboost.core.CatBoostRegressor at 0x1457893d0>]

# %% [markdown]
# ## #03. 앙상블
#
# ### [1] 선정된 모형에 대한 Voting

# %%
blended = s.blend_models(estimator_list=best5models, fold=5)
blended
# Out:
# <style type="text/css">
# #T_dcffd_row5_col0, #T_dcffd_row5_col1, #T_dcffd_row5_col2, #T_dcffd_row5_col3, #T_dcffd_row5_col4, #T_dcffd_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_dcffd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dcffd_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_dcffd_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_dcffd_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_dcffd_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_dcffd_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_dcffd_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dcffd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dcffd_row0_col0" class="data row0 col0" >0.1922</td>
#       <td id="T_dcffd_row0_col1" class="data row0 col1" >0.0578</td>
#       <td id="T_dcffd_row0_col2" class="data row0 col2" >0.2404</td>
#       <td id="T_dcffd_row0_col3" class="data row0 col3" >0.6162</td>
#       <td id="T_dcffd_row0_col4" class="data row0 col4" >0.0138</td>
#       <td id="T_dcffd_row0_col5" class="data row0 col5" >0.0117</td>
#     </tr>
#     <tr>
#       <th id="T_dcffd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_dcffd_row1_col0" class="data row1 col0" >0.1795</td>
#       <td id="T_dcffd_row1_col1" class="data row1 col1" >0.0475</td>
#       <td id="T_dcffd_row1_col2" class="data row1 col2" >0.2180</td>
#       <td id="T_dcffd_row1_col3" class="data row1 col3" >0.7314</td>
#       <td id="T_dcffd_row1_col4" class="data row1 col4" >0.0126</td>
#       <td id="T_dcffd_row1_col5" class="data row1 col5" >0.0110</td>
#     </tr>
#     <tr>
#       <th id="T_dcffd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_dcffd_row2_col0" class="data row2 col0" >0.1467</td>
#       <td id="T_dcffd_row2_col1" class="data row2 col1" >0.0330</td>
#       <td id="T_dcffd_row2_col2" class="data row2 col2" >0.1817</td>
#       <td id="T_dcffd_row2_col3" class="data row2 col3" >0.7925</td>
#       <td id="T_dcffd_row2_col4" class="data row2 col4" >0.0106</td>
#       <td id="T_dcffd_row2_col5" class="data row2 col5" >0.0090</td>
#     </tr>
#     <tr>
#       <th id="T_dcffd_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_dcffd_row3_col0" class="data row3 col0" >0.1535</td>
#       <td id="T_dcffd_row3_col1" class="data row3 col1" >0.0364</td>
#       <td id="T_dcffd_row3_col2" class="data row3 col2" >0.1908</td>
#       <td id="T_dcffd_row3_col3" class="data row3 col3" >0.6840</td>
#       <td id="T_dcffd_row3_col4" class="data row3 col4" >0.0110</td>
#       <td id="T_dcffd_row3_col5" class="data row3 col5" >0.0094</td>
#     </tr>
#     <tr>
#       <th id="T_dcffd_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_dcffd_row4_col0" class="data row4 col0" >0.1757</td>
#       <td id="T_dcffd_row4_col1" class="data row4 col1" >0.0494</td>
#       <td id="T_dcffd_row4_col2" class="data row4 col2" >0.2223</td>
#       <td id="T_dcffd_row4_col3" class="data row4 col3" >0.5888</td>
#       <td id="T_dcffd_row4_col4" class="data row4 col4" >0.0128</td>
#       <td id="T_dcffd_row4_col5" class="data row4 col5" >0.0107</td>
#     </tr>
#     <tr>
#       <th id="T_dcffd_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_dcffd_row5_col0" class="data row5 col0" >0.1695</td>
#       <td id="T_dcffd_row5_col1" class="data row5 col1" >0.0448</td>
#       <td id="T_dcffd_row5_col2" class="data row5 col2" >0.2106</td>
#       <td id="T_dcffd_row5_col3" class="data row5 col3" >0.6826</td>
#       <td id="T_dcffd_row5_col4" class="data row5 col4" >0.0121</td>
#       <td id="T_dcffd_row5_col5" class="data row5 col5" >0.0104</td>
#     </tr>
#     <tr>
#       <th id="T_dcffd_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_dcffd_row6_col0" class="data row6 col0" >0.0169</td>
#       <td id="T_dcffd_row6_col1" class="data row6 col1" >0.0090</td>
#       <td id="T_dcffd_row6_col2" class="data row6 col2" >0.0215</td>
#       <td id="T_dcffd_row6_col3" class="data row6 col3" >0.0744</td>
#       <td id="T_dcffd_row6_col4" class="data row6 col4" >0.0012</td>
#       <td id="T_dcffd_row6_col5" class="data row6 col5" >0.0010</td>
#     </tr>
#   </tbody>
# </table>
# VotingRegressor(estimators=[('Ridge Regression', Ridge(random_state=52)),
#                             ('Linear Regression', LinearRegression(n_jobs=-1)),
#                             ('Light Gradient Boosting Machine',
#                              LGBMRegressor(n_jobs=-1, random_state=52)),
#                             ('Support Vector Regression', SVR()),
#                             ('CatBoost Regressor',
#                              <catboost.core.CatBoostRegressor object at 0x1457f3890>)],
#                 n_jobs=-1)

# %%
# %%time
tuned = s.tune_model(
    estimator=blended, 
    optimize="RMSE",
    n_iter=30,
    fold=5,
    choose_better=True,
    verbose=False,
    early_stopping=True,

    # 하이퍼파라미터 탐색 방법(grid=전체탐색, random=무작위탐색)
    search_algorithm="grid",

    # 직접 하이퍼파라미터 범위 구성하기 (생략할 경우 자동 구성함)
    custom_grid={
        "Ridge Regression__alpha": [0.01, 0.1, 1, 10, 100],
        
        "Light Gradient Boosting Machine__n_estimators": [200],          # [100, 300, 500],
        "Light Gradient Boosting Machine__learning_rate": [0.05, 0.1],   # [0.01, 0.05, 0.1],
        "Light Gradient Boosting Machine__num_leaves": [31, 63],         # [15, 31, 63],
        "Light Gradient Boosting Machine__max_depth": [-1, 5],           # [-1, 3, 5, 7],
        "Light Gradient Boosting Machine__min_child_samples": [20, 50],  # [10, 20, 50],
        "Light Gradient Boosting Machine__subsample": [0.8],             # [0.6, 0.8, 1.0],
        "Light Gradient Boosting Machine__reg_alpha": [0, 0.1, 1],
        "Light Gradient Boosting Machine__reg_lambda": [0, 1, 5],

        "Support Vector Regression__kernel": ["rbf"],   # 수업·실습 기본은 rbf 고정
        "Support Vector Regression__C": [0.1, 1, 10, 100],
        "Support Vector Regression__epsilon": [0.01, 0.05, 0.1, 0.2],
        "Support Vector Regression__gamma": ["scale", "auto", 0.01, 0.1, 1],

        "CatBoost Regressor__iterations": [300, 500],
        "CatBoost Regressor__learning_rate": [0.01, 0.03, 0.1],
        "CatBoost Regressor__depth": [4, 6, 8],
        "CatBoost Regressor__l2_leaf_reg": [1, 3, 5],
        "CatBoost Regressor__subsample": [0.8, 1.0],
    }
)
tuned

# %% [markdown]
# ### [2] 하이퍼파라미터 확인

# %%
tuned.get_params()

# %% [markdown]
# ## #04. 분석 결과 확인하기
#
# ### [1] 훈련, 검증 데이터 추출
#
# 전처리가 완료된 데이터를 반환한다.
#
# `get_config()`는 pycaret.regressor 객체의 메서드
#
# #### 각 데이터 추출

# %%
# 원본 독립변수(분할전)
x = s.get_config("X")
y = s.get_config("y")

# 훈련 데이터 (데이터 변환 전)
x_train = s.get_config("X_train")
y_train = s.get_config("y_train")

# 테스트 데이터 (데이터 변환 전)
x_test = s.get_config("X_test")
y_test = s.get_config("y_test")

# 변환된 훈련 데이터
x_train_transformed = s.get_config("X_train_transformed")
y_train_transformed = s.get_config("y_train_transformed")

# 변환된 테스트 데이터
x_test_transformed = s.get_config("X_test_transformed")
y_test_transformed = s.get_config("y_test_transformed")

# 변환된 훈련+테스트 데이터 셋
x_transformed = concat([x_train_transformed, x_test_transformed])
y_transformed = concat([y_train_transformed, y_test_transformed])

(x.shape, y.shape), (x_train.shape, y_train.shape), (x_test.shape, y_test.shape), (x_train_transformed.shape, y_train_transformed.shape), (x_test_transformed.shape, y_test_transformed.shape)

# %% [markdown]
# ### [2] 성능평가
#
# #### 시각화 초기화

# %%
init_pyplot()

# %% [markdown]
# #### 성능평가 지표 확인

# %%
#%%time
hs_get_score_cv(tuned, x_test_transformed, y_test_transformed, x_transformed, y_transformed)

# %% [markdown]
# ### [3] 변수 중요도 확인

# %%
hs_feature_importance(tuned, x_train_transformed, y_train_transformed)

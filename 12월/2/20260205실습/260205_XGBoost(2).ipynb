# %% [markdown]
# ## 패키지 및 데이터 로드

# %%
# ── 사용자 정의 모듈
from hossam import *
# ── 표준 라이브러리
import numpy as np

# ── 서드파티 라이브러리
import seaborn as sns
from matplotlib import pyplot as plt
from pandas import DataFrame

# ── 머신러닝 (scikit-learn)
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import (
    train_test_split,
    GridSearchCV,
    learning_curve,
)
from sklearn.metrics import (
    r2_score,
    mean_absolute_error,
    mean_squared_error,
    mean_absolute_percentage_error,
)
from sklearn.svm import SVR
from sklearn.inspection import permutation_importance
from sklearn.tree import DecisionTreeRegressor

from sklearn.ensemble import AdaBoostRegressor, GradientBoostingRegressor

# %% [markdown]
# ### 데이터 가져오기 + 인덱스, 타입변환

# %%
origin = load_data("restaurant_sales_preprocessed")
origin.set_index("date", inplace=True)
origin["holiday"] = origin["holiday"].astype("category")
origin["weekend"] = origin["weekend"].astype("category")
origin.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 origin = load_data("restaurant_sales_preprocessed")
#       2 origin.set_index("date", inplace=True)
#       3 origin["holiday"] = origin["holiday"].astype("category")
#
# NameError: name 'load_data' is not defined

# %% [markdown]
# # 패키지 및 데이터

# %%
# ==================================================
# 기본 라이브러리
# ==================================================
import numpy as np
import seaborn as sb
import pandas as pd

from matplotlib import pyplot as plt
from pandas import DataFrame, concat



# ==================================================
# scikit-learn 공통
# ==================================================
from sklearn.pipeline import Pipeline

from sklearn.model_selection import (
    train_test_split,
    GridSearchCV,
    learning_curve,
)

from sklearn.preprocessing import StandardScaler


# ==================================================
# 분류 모델
# ==================================================
from sklearn.linear_model import (
    LogisticRegression,
    SGDClassifier,
)

from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import (
    log_loss,
    confusion_matrix,
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_curve,
    roc_auc_score,
)

from sklearn.ensemble import (
    RandomForestClassifier,
    GradientBoostingClassifier,
)


# ==================================================
# Boosting 계열
# ==================================================
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier


# ==================================================
# 사용자 정의 모듈
# ==================================================
from hossam import *

# %% [markdown]
# # origin

# %%
origin = pd.read_csv("kta-county-data-december-2025.csv")
origin.head()
origin.info()
origin.shape
origin.head()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 94923 entries, 0 to 94922
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   RPT_DATE      94923 non-null  str
#  1   RPT_YR        94923 non-null  str
#  2   GEOGRAPHY     94923 non-null  str
#  3   SVC_DESC      94923 non-null  str
#  4   AMOUNT        62812 non-null  str
#  5   AMOUNT_ANNOT  32119 non-null  float64
#  6   AMOUNT_TYPE   94903 non-null  str
# dtypes: float64(1), str(6)
# memory usage: 5.1 MB
#     RPT_DATE  RPT_YR GEOGRAPHY                   SVC_DESC   AMOUNT  \
# 0  6/30/2020  FY1920   Alameda                        ALL      410
# 1  6/30/2020  FY1920   Alameda                        ALL  4582253
# 2  6/30/2020  FY1920   Alameda  CASE_MANAGEMENT/BROKERAGE       59
# 3  6/30/2020  FY1920   Alameda  CASE_MANAGEMENT/BROKERAGE    28843
# 4  6/30/2020  FY1920   Alameda  CASE_MANAGEMENT/BROKERAGE    67459
#
#    AMOUNT_ANNOT AMOUNT_TYPE
# 0           NaN     MEMBERS
# 1           NaN     DOLLARS
# 2           NaN     MEMBERS
# 3           NaN     MINUTES
# 4           NaN     DOLLARS

# %% [markdown]
# ### 타입변환

# %%
# 1. pd.to_numeric함수에서 AMOUNT 컬럼의 콤마(,) 제거 및 숫자형 변환
origin['AMOUNT'] = origin['AMOUNT'].astype(str).str.replace(',', '')


origin['AMOUNT'] = pd.to_numeric(origin['AMOUNT'], errors='coerce')


origin.info()
origin["AMOUNT_ANNOT"]
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 94923 entries, 0 to 94922
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   RPT_DATE      94923 non-null  str
#  1   RPT_YR        94923 non-null  str
#  2   GEOGRAPHY     94923 non-null  str
#  3   SVC_DESC      94923 non-null  str
#  4   AMOUNT        62804 non-null  float64
#  5   AMOUNT_ANNOT  32119 non-null  float64
#  6   AMOUNT_TYPE   94903 non-null  str
# dtypes: float64(2), str(5)
# memory usage: 5.1 MB
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 94918   2.000
# 94919   2.000
# 94920   1.000
# 94921   1.000
# 94922   1.000
# Name: AMOUNT_ANNOT, Length: 94923, dtype: float64

# %% [markdown]
# # df1

# %% [markdown]
# ### AMOUNT_TYPE 결측치 제거

# %%
# AMOUNT_TYPE이 없는 행 제거
df1 = df1.dropna(subset=['AMOUNT_TYPE'])

# %%
before = origin.copy()
after = origin.dropna()

before_mean = before.mean(numeric_only = True)
after_mean = after.mean(numeric_only=True)

#결측치 제거 전, 결측치 제거 후 비교 
df = pd.DataFrame(
    {
        "결측치 제거 전 평균": before_mean,
        "결측치 제거 후 평균": after_mean
    }
)

df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 2 entries, AMOUNT to AMOUNT_ANNOT
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   결측치 제거 전 평균  2 non-null      float64
#  1   결측치 제거 후 평균  0 non-null      float64
# dtypes: float64(2)
# memory usage: 48.0+ bytes

# %% [markdown]
# ### 결측치에 0을 넣었을 때와 5를 넣었을 때의 평균 차이

# %%
df1 = origin.copy()
df1['AMOUNT_ANNOT'] = df1['AMOUNT_ANNOT'].fillna(0)

df1["AMOUNT"] = pd.to_numeric(df1['AMOUNT'].astype(str).str.replace(',', ''), errors='coerce').fillna(0)

before_mean = origin[['AMOUNT', 'AMOUNT_ANNOT']].mean(numeric_only=True)
after_mean = df1[['AMOUNT', 'AMOUNT_ANNOT']].mean(numeric_only=True)


comparison = pd.DataFrame({
    "결측치 처리 전 평균": before_mean,
    "결측치 처리 후 평균": after_mean
})
comparison
# Out:
#               결측치 처리 전 평균  결측치 처리 후 평균
# AMOUNT        1732146.126  1146041.584
# AMOUNT_ANNOT        1.076        0.364

# %%
df1["GEOGRAPHY"].unique()
# Out:
# <StringArray>
# [        'Alameda',          'Amador',           'Butte',       'Calaveras',
#           'Colusa',    'Contra Costa',       'Del Norte',       'El Dorado',
#           'Fresno',           'Glenn',        'Humboldt',        'Imperial',
#             'Inyo',            'Kern',           'Kings',            'Lake',
#           'Lassen',     'Los Angeles',          'Madera',           'Marin',
#         'Mariposa',       'Mendocino',          'Merced',           'Modoc',
#             'Mono',        'Monterey',            'Napa',          'Nevada',
#           'Orange',          'Placer',          'Plumas',       'Riverside',
#            'STATE',      'Sacramento',      'San Benito',  'San Bernardino',
#        'San Diego',   'San Francisco',     'San Joaquin', 'San Luis Obispo',
#        'San Mateo',   'Santa Barbara',     'Santa Clara',      'Santa Cruz',
#           'Shasta',        'Siskiyou',          'Solano',          'Sonoma',
#       'Stanislaus',     'Sutter/Yuba',          'Tehama',         'Trinity',
#           'Tulare',        'Tuolumne',         'Ventura',            'Yolo',
#           'Alpine']
# Length: 57, dtype: str

# %% [markdown]
# ### GEOGRAPHY칼럼의 항목들의 개수 확인

# %%
# 94923개의 행 수를 value_counts()를 활용하여 GEOGRAPHY칼럼의 항목 개수 셈
# 개수를 세고 데이터프레임으로 변환
geography_counts = df1["GEOGRAPHY"].value_counts().reset_index()

# GEOGRAPY는 범주형 변수, 그리고 COUNT변수는 value_counts()를 통해 출력된 각 항목들의 결과값
# 94923개의 행 수를 두 개의 칼럼을 통해 항목 수를 셌다
geography_counts.columns = ['GEOGRAPHY', 'COUNT']

geography_counts.head()
# Out:
#         GEOGRAPHY  COUNT
# 0           STATE   4394
# 1  San Bernardino   3472
# 2       San Diego   3206
# 3     Los Angeles   3009
# 4            Kern   2688

# %% [markdown]
# # d_2

# %% [markdown]
# ### stats_comparison
# STATS 제거 전, 후의 왜도 & 첨도 값

# %%
import pandas as pd

# 1. STATE 제거한 데이터 생성
d_2 = d_1[d_1['GEOGRAPHY'] != 'STATE'].copy()

# 2. 전/후 수치 계산
stats_comparison = pd.DataFrame({
    "제거 전 (d_1)": [d_1['AMOUNT'].skew(), d_1['AMOUNT'].kurt()],
    "제거 후 (d_2)": [d_2['AMOUNT'].skew(), d_2['AMOUNT'].kurt()]
}, index=['왜도(Skewness)', '첨도(Kurtosis)'])

# 3. 결과 확인
print("--- STATE 제거 전/후 AMOUNT 컬럼 통계 비교 ---")
stats_comparison
# Out:
# --- STATE 제거 전/후 AMOUNT 컬럼 통계 비교 ---
#               제거 전 (d_1)  제거 후 (d_2)
# 왜도(Skewness)      20.665      20.629
# 첨도(Kurtosis)     522.595     534.840

# %% [markdown]
# ### EDA

# %%
# 왜도 판정 함수
# Pandas의 apply나 조건문으로 열을 바로 추가하는 것이 훨씬 효율적입니다.
def check_skew(x):
    if abs(x) < 0.5: return "대칭"
    elif abs(x) < 1: return "약간 편향"
    else:return "심한 편향"

def check_curt(x):
    if abs(x) < 1:return "적정"
    elif (x) >= 1: return "뽀족함(이상치 많음)"
    else:return "완만함"

# %%
SVC_time = d_2[d_2['특정 정신건강 서비스'] == 'CRISIS_INTERVENTION'].set_index('RPT_DATE')

SVC_time.plot(figsize=(10,5))
# Out:
# <Axes: xlabel='RPT_DATE'>

# %% [markdown]
# ### d

# %%
d = df1.describe()

d = pd.DataFrame(
    {
        "왜도":df1.skew(numeric_only=  True),
        "첨도": df1.kurt(numeric_only= True)
    }
)


# 데이터프레임 d에 판정 결과 열 추가
d["왜도 판정"] = d["왜도"].apply(check_skew)
d["첨도 판정"] = d["첨도"].apply(check_skew)

d
# 94923개의 행 수 중 왜도가 20.
# Out:
#                  왜도      첨도  왜도 판정  첨도 판정
# AMOUNT       20.665 522.595  심한 편향  심한 편향
# AMOUNT_ANNOT  1.070   0.084  심한 편향     대칭

# %% [markdown]
# > STATE제거 전 시각화

# %%
print(df1['AMOUNT'].describe())

import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10,6))
sns.histplot(df1["AMOUNT"], bins=50, kde=True)
plt.title('Amount Distribution')
plt.show()
# Out:
# count       94923.000
# mean      1146041.584
# std      10756159.214
# min             0.000
# 25%             0.000
# 50%           225.000
# 75%        100266.000
# max     352935869.100
# Name: AMOUNT, dtype: float64

# %% [markdown]
# 왜도 (Skewness):$|값| < 0.5$: 대칭에 가까움 (Normal)$0.5 \le |값| < 1$: 약간 치우침 (Moderate)$|값| \ge 1$: 심하게 치우침 (Highly Skewed)첨도 (Kurtosis):$|값| < 1$: 정규분포와 비슷함 (Mesokurtic)$값 \ge 1$: 중앙에 집중되고 꼬리가 두꺼움 (Leptokurtic)$값 \le -1$: 분포가 완만함 (Platykurtic)

# %% [markdown]
# ### SVC_DESC 변수 value_counts()

# %%
df1["SVC_DESC"].value_counts()
# Out:
# SVC_DESC
# ICC                            13959
# MENTAL_HEALTH_SVCS             11485
# CASE_MANAGEMENT/BROKERAGE      10347
# MEDICATION_SUPPORT_SVCS         9948
# IHBS                            9432
# ALL                             9418
# CRISIS_INTERVENTION             8406
# THERAPEUTIC_BEHAVIORAL_SVCS     7050
# CRISIS_STABILIZATION            3210
# TFC                             2373
# PSYCHIATRIC_HEALTH_FACILITY     2076
# CRISIS_RESIDENTIAL_TX_SVCS      1557
# SDMC_HOSPITAL_INPATIENT         1546
# FULL_DAY_TX_INTENSIVE           1083
# SELF_HELP_PEER_SVCS              765
# ADULT_RESIDENTIAL_TX_SVCS        693
# FULL_DAY_REHAB                   540
# BH_PREVENTION_EDUCATION_SVC      507
# INPATIENT_ADMIN                  408
# MOBILE_CRISIS                    120
# Name: count, dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 94923 entries, 0 to 94922
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   RPT_DATE      94923 non-null  str
#  1   RPT_YR        94923 non-null  str
#  2   GEOGRAPHY     94923 non-null  str
#  3   SVC_DESC      94923 non-null  str
#  4   AMOUNT        94923 non-null  float64
#  5   AMOUNT_ANNOT  94923 non-null  float64
#  6   AMOUNT_TYPE   94903 non-null  str
# dtypes: float64(2), str(5)
# memory usage: 5.1 MB

# %% [markdown]
# # d_1

# %%
# inplace=True를 사용하여 바로 칼럼의 이름을 바꾼다
d_1 = df1.copy()

d_1.rename(columns = {"SVC_DESC":"특정 정신건강 서비스"}, inplace=True)

d_1
# Out:
#         RPT_DATE  RPT_YR GEOGRAPHY                  특정 정신건강 서비스      AMOUNT  \
# 0      6/30/2020  FY1920   Alameda                          ALL     410.000
# 1      6/30/2020  FY1920   Alameda                          ALL 4582253.000
# 2      6/30/2020  FY1920   Alameda    CASE_MANAGEMENT/BROKERAGE      59.000
# 3      6/30/2020  FY1920   Alameda    CASE_MANAGEMENT/BROKERAGE   28843.000
# 4      6/30/2020  FY1920   Alameda    CASE_MANAGEMENT/BROKERAGE   67459.000
# ...          ...     ...       ...                          ...         ...
# 94918  12/2/2025  FY2425      Yolo          SELF_HELP_PEER_SVCS       0.000
# 94919  12/2/2025  FY2425      Yolo          SELF_HELP_PEER_SVCS       0.000
# 94920  12/2/2025  FY2425      Yolo  THERAPEUTIC_BEHAVIORAL_SVCS       0.000
# 94921  12/2/2025  FY2425      Yolo  THERAPEUTIC_BEHAVIORAL_SVCS       0.000
# 94922  12/2/2025  FY2425      Yolo  THERAPEUTIC_BEHAVIORAL_SVCS       0.000
#
#        AMOUNT_ANNOT AMOUNT_TYPE
# 0             0.000     MEMBERS
# 1             0.000     DOLLARS
# 2             0.000     MEMBERS
# 3             0.000     MINUTES
# 4             0.000     DOLLARS
# ...             ...         ...
# 94918         2.000     MINUTES
# 94919         2.000     DOLLARS
# 94920         1.000     DOLLARS
# 94921         1.000     MEMBERS
# 94922         1.000     MINUTES
#
# [94923 rows x 7 columns]

# %%
d_2["특정 정신건강 서비스"].unique()
# Out:
# <StringArray>
# [                        'ALL',   'CASE_MANAGEMENT/BROKERAGE',
#          'CRISIS_INTERVENTION',  'CRISIS_RESIDENTIAL_TX_SVCS',
#         'CRISIS_STABILIZATION',       'FULL_DAY_TX_INTENSIVE',
#                          'ICC',                        'IHBS',
#              'INPATIENT_ADMIN',     'MEDICATION_SUPPORT_SVCS',
#           'MENTAL_HEALTH_SVCS', 'PSYCHIATRIC_HEALTH_FACILITY',
#      'SDMC_HOSPITAL_INPATIENT', 'THERAPEUTIC_BEHAVIORAL_SVCS',
#                          'TFC',              'FULL_DAY_REHAB',
#    'ADULT_RESIDENTIAL_TX_SVCS', 'BH_PREVENTION_EDUCATION_SVC',
#          'SELF_HELP_PEER_SVCS',               'MOBILE_CRISIS']
# Length: 20, dtype: str

# %% [markdown]
# ### 시계열 분석

# %%
df1
# Out:
#         RPT_DATE  RPT_YR GEOGRAPHY                     SVC_DESC      AMOUNT  \
# 0     2020-06-30  FY1920   Alameda                          ALL     410.000
# 1     2020-06-30  FY1920   Alameda                          ALL 4582253.000
# 2     2020-06-30  FY1920   Alameda    CASE_MANAGEMENT/BROKERAGE      59.000
# 3     2020-06-30  FY1920   Alameda    CASE_MANAGEMENT/BROKERAGE   28843.000
# 4     2020-06-30  FY1920   Alameda    CASE_MANAGEMENT/BROKERAGE   67459.000
# ...          ...     ...       ...                          ...         ...
# 94918 2025-12-02  FY2425      Yolo          SELF_HELP_PEER_SVCS       0.000
# 94919 2025-12-02  FY2425      Yolo          SELF_HELP_PEER_SVCS       0.000
# 94920 2025-12-02  FY2425      Yolo  THERAPEUTIC_BEHAVIORAL_SVCS       0.000
# 94921 2025-12-02  FY2425      Yolo  THERAPEUTIC_BEHAVIORAL_SVCS       0.000
# 94922 2025-12-02  FY2425      Yolo  THERAPEUTIC_BEHAVIORAL_SVCS       0.000
#
#        AMOUNT_ANNOT AMOUNT_TYPE
# 0             0.000     MEMBERS
# 1             0.000     DOLLARS
# 2             0.000     MEMBERS
# 3             0.000     MINUTES
# 4             0.000     DOLLARS
# ...             ...         ...
# 94918         2.000     MINUTES
# 94919         2.000     DOLLARS
# 94920         1.000     DOLLARS
# 94921         1.000     MEMBERS
# 94922         1.000     MINUTES
#
# [94923 rows x 7 columns]

# %% [markdown]
# ### 시각화

# %% [markdown]
# ### STATE 제거 전

# %%
df1['SVC_DESC'].describe()
# Out:
# count     94923
# unique       20
# top         ICC
# freq      13959
# Name: SVC_DESC, dtype: object

# %% [markdown]
# > AMOUNT_TYPE의 MEMBERS, DOLLARS, MINUTES를 합친 값

# %%
# RPT_DATE를 날짜 형식으로 변환 (이미 하셨다면 통과)
df1['RPT_DATE'] = pd.to_datetime(df1['RPT_DATE'])

# 특정 서비스(예: ICC)의 월별 이용량 추이 추출
time_series = df1[df1['SVC_DESC'] == 'ICC'].set_index('RPT_DATE')
monthly_trend = time_series['AMOUNT'].resample('MS').sum()

# %%
import matplotlib.pyplot as plt

# 그래프 크기 설정
plt.figure(figsize=(12, 6))

# 데이터 플로팅
monthly_trend.plot(marker='o', linestyle='-')

# 제목 및 라벨 추가
plt.title('Monthly ICC Service Trend')
plt.xlabel('Date')
plt.ylabel('Total Amount')
plt.grid(True)

plt.show()

# %% [markdown]
# 현재 시각화 결과는 df1(STATE 포함)을 기준으로 MEMBERS, MINUTES, DOLLARS 단위를 모두 합친 수치입니다.<br>
# 실무적 해석: 따라서 이 그래프는 "정확한 인원수"가 아니라, **"시스템 전체의 활동 강도(Total Intensity)"**가 어떻게 변하고 있는지를 보여주는 통합 지표로 해석하는 것이 적절합니다.

# %% [markdown]
# ### AMOUNT_TYPE값 시각화 코드

# %%
d_2[d_2['특정 정신건강 서비스'] == 'ICC'].describe()
# Out:
#             AMOUNT  AMOUNT_ANNOT
# count    13698.000     13698.000
# mean    815078.738         0.174
# std    4021743.882         0.432
# min          0.000         0.000
# 25%         94.000         0.000
# 50%      18083.500         0.000
# 75%     310313.500         0.000
# max   71364745.350         2.000

# %%
import matplotlib.pyplot as plt

# 1. ICC 서비스 데이터만 추출
icc_data = d_2[d_2['특정 정신건강 서비스'] == 'ICC']

# 2. 분석할 세 가지 단위 필터링
target_types = ['MEMBERS', 'DOLLARS', 'MINUTES']
filtered_icc = icc_data[icc_data['AMOUNT_TYPE'].isin(target_types)]

# 3. 피벗 테이블 생성 (날짜별, 단위별 합계)
icc_pivot = filtered_icc.pivot_table(index='RPT_DATE', 
                                    columns='AMOUNT_TYPE', 
                                    values='AMOUNT', 
                                    aggfunc='sum')

# 4. 월별 리샘플링 (Month Start)
monthly_icc = icc_pivot.resample('MS').sum()

# 5. 시각화: 3행 1열의 서브플롯 생성
fig, axes = plt.subplots(3, 1, figsize=(12, 15), sharex=True)

colors = ['#1f77b4', '#2ca02c', '#ff7f0e'] # 파랑(인원), 초록(비용), 주황(시간)

for ax, dtype, color in zip(axes, target_types, colors):
    if dtype in monthly_icc.columns:
        monthly_icc[dtype].plot(ax=ax, marker='o', color=color, linewidth=2)
        ax.set_title(f'Monthly ICC {dtype} Trend', fontsize=14, fontweight='bold')
        ax.set_ylabel(dtype, fontsize=12)
        ax.grid(True, linestyle='--', alpha=0.7)

plt.xlabel('Date', fontsize=12)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# 1. RPT_DATE를 날짜 형식으로 변환 (d_2에 적용)
d_2['RPT_DATE'] = pd.to_datetime(d_2['RPT_DATE'])

# 2. 특정 서비스(예: ICC)와 특정 단위(예: MEMBERS) 필터링
# 단위를 고정하지 않으면 시간(MINUTES)과 인원(MEMBERS)이 합쳐져 수치가 왜곡될 수 있습니다.
target_service = 'ICC' 
target_type = 'MEMBERS'

filtered_data = d_2[(d_2['특정 정신건강 서비스'] == target_service) & 
                    (d_2['AMOUNT_TYPE'] == target_type)]

# 3. 날짜를 인덱스로 설정하고 월별 합계 계산
monthly_trend = filtered_data.set_index('RPT_DATE')['AMOUNT'].resample('MS').sum()

# 4. 선 그래프 시각화
plt.figure(figsize=(12, 6))
monthly_trend.plot(marker='o', color='b', linestyle='-')

plt.title(f'Monthly Trend of {target_service} ({target_type}) - State Excluded', fontsize=14)
plt.xlabel('Date')
plt.ylabel('Total Amount')
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ### 날짜별 합계

# %%
# 1. 날짜별로 합쳐진 실제 수치 확인
print(monthly_trend.head())

# 2. 그래프 그리기
monthly_trend.plot()
# Out:
# RPT_DATE
# 2020-06-01   78777.000
# 2020-07-01       0.000
# 2020-08-01   83464.000
# 2020-09-01       0.000
# 2020-10-01       0.000
# Freq: MS, Name: AMOUNT, dtype: float64
# <Axes: xlabel='RPT_DATE'>

# %% [markdown]
# # service_pivot 파생변수 생성<br>
# 1. 특정 정신건강 서비스 인덱스에 매칭되는 AMOUNT_TYPE의 항목들을 파생변수로** 생성<br>
# 2. 파생변수인 MINUTES와 MEMBERS변수에서 MINUTES/MEMBERS하여 **인당 투입시간**을 계산<br>
#
# ex)수요는 적지만 한 번 발생하면 아주 많은 자원이 들어가는 '고위험군 대상 서비스'임을 뜻합니다.

# %%
# 1. AMOUNT_TYPE을 컬럼으로 올리기 (파생변수화)
# 서비스별로 인원(MEMBERS), 시간(MINUTES), 비용(DOLLARS)을 한 줄에 나열합니다.
service_pivot = d_2.pivot_table(index='특정 정신건강 서비스', 
                                columns='AMOUNT_TYPE', 
                                values='AMOUNT', 
                                aggfunc='sum').fillna(0) #aggfunc:계산을 어떻게 할지

# 2. 분석을 돕는 추가 파생변수(비율) 생성
# '인당 투입 시간'과 '인당 투입 비용'을 계산하면 서비스의 성격이 명확해집니다.
if 'MEMBERS' in service_pivot.columns:
    if 'MINUTES' in service_pivot.columns:
        service_pivot['인당_투입시간(MIN/MEM)'] = service_pivot['MINUTES'] / service_pivot['MEMBERS']
    if 'DOLLARS' in service_pivot.columns:
        service_pivot['인당_투입비용(DOL/MEM)'] = service_pivot['DOLLARS'] / service_pivot['MEMBERS']

# 3. 결과 확인
print(service_pivot.sort_values(by='MEMBERS', ascending=False))
# Out:
# AMOUNT_TYPE                       DAYS         DOLLARS       HOURS  \
# 특정 정신건강 서비스
# ALL                              0.000 24066666586.170       0.000
# ICC                              0.000  8523151040.480       0.000
# IHBS                             0.000  5519209454.640       0.000
# MENTAL_HEALTH_SVCS               0.000  6646027629.570       0.000
# CASE_MANAGEMENT/BROKERAGE        0.000   505458111.020       0.000
# MEDICATION_SUPPORT_SVCS          0.000   702468458.960       0.000
# CRISIS_STABILIZATION             0.000   207472679.430 2003010.940
# CRISIS_INTERVENTION              0.000   114754419.810       0.000
# THERAPEUTIC_BEHAVIORAL_SVCS      0.000   778336807.570       0.000
# SELF_HELP_PEER_SVCS              0.000    44296403.310       0.000
# FULL_DAY_REHAB                   0.000   103716892.000 3197976.000
# SDMC_HOSPITAL_INPATIENT      32513.000    46232180.470       0.000
# FULL_DAY_TX_INTENSIVE            0.000    80616076.000 2438454.000
# PSYCHIATRIC_HEALTH_FACILITY 139340.000    91033183.600       0.000
# TFC                         172531.540    97636143.720       0.000
# BH_PREVENTION_EDUCATION_SVC      0.000       44032.840       0.000
# MOBILE_CRISIS                    0.000        2073.440       0.000
# INPATIENT_ADMIN                  0.000           0.000       0.000
# CRISIS_RESIDENTIAL_TX_SVCS       0.000           0.000       0.000
# ADULT_RESIDENTIAL_TX_SVCS        0.000           0.000       0.000
#
# AMOUNT_TYPE                     MEMBERS        MINUTES  인당_투입시간(MIN/MEM)  \
# 특정 정신건강 서비스
# ALL                         3136700.000          0.000             0.000
# ICC                         2635321.000 2639162196.030          1001.458
# IHBS                         956146.000 1759761514.800          1840.474
# MENTAL_HEALTH_SVCS           948020.000 1609675075.230          1697.934
# CASE_MANAGEMENT/BROKERAGE    378131.000  131688925.370           348.263
# MEDICATION_SUPPORT_SVCS      352002.000  111626868.750           317.120
# CRISIS_STABILIZATION          88223.000          0.000             0.000
# CRISIS_INTERVENTION           79883.000   19399012.200           242.843
# THERAPEUTIC_BEHAVIORAL_SVCS   61545.000  245555428.350          3989.852
# SELF_HELP_PEER_SVCS           11820.000    7674625.000           649.291
# FULL_DAY_REHAB                 5351.000          0.000             0.000
# SDMC_HOSPITAL_INPATIENT        4544.000         90.000             0.020
# FULL_DAY_TX_INTENSIVE          3274.000          0.000             0.000
# PSYCHIATRIC_HEALTH_FACILITY    2266.000          0.000             0.000
# TFC                            2233.000          0.000             0.000
# BH_PREVENTION_EDUCATION_SVC     131.000      31740.000           242.290
# MOBILE_CRISIS                    11.000        780.000            70.909
# INPATIENT_ADMIN                   0.000          0.000               NaN
# CRISIS_RESIDENTIAL_TX_SVCS        0.000          0.000               NaN
# ADULT_RESIDENTIAL_TX_SVCS         0.000          0.000               NaN
#
# AMOUNT_TYPE                  인당_투입비용(DOL/MEM)
# 특정 정신건강 서비스
# ALL                                  7672.607
# ICC                                  3234.198
# IHBS                                 5772.350
# MENTAL_HEALTH_SVCS                   7010.430
# CASE_MANAGEMENT/BROKERAGE            1336.728
# MEDICATION_SUPPORT_SVCS              1995.638
# CRISIS_STABILIZATION                 2351.685
# CRISIS_INTERVENTION                  1436.531
# THERAPEUTIC_BEHAVIORAL_SVCS         12646.629
# SELF_HELP_PEER_SVCS                  3747.581
# FULL_DAY_REHAB                      19382.712
# SDMC_HOSPITAL_INPATIENT             10174.335
# FULL_DAY_TX_INTENSIVE               24623.114
# PSYCHIATRIC_HEALTH_FACILITY         40173.514
# TFC                                 43724.202
# BH_PREVENTION_EDUCATION_SVC           336.129
# MOBILE_CRISIS                         188.495
# INPATIENT_ADMIN                           NaN
# CRISIS_RESIDENTIAL_TX_SVCS                NaN
# ADULT_RESIDENTIAL_TX_SVCS                 NaN

# %% [markdown]
# ### members_df
# 지역별 서비스 수혜 인원(MEMBERS) 분석 코드

# %%
# 1. 이용자 수(MEMBERS) 데이터만 추출
members_df = d_2[d_2['AMOUNT_TYPE'] == 'MEMBERS']

# 2. 지역별, 서비스별 MEMBERS 합계 계산 (피벗 테이블)
# 행(Index)은 지역, 열(Columns)은 서비스 종류, 값(Values)은 인원수
geo_service_members = members_df.pivot_table(index='GEOGRAPHY', 
                                            columns='특정 정신건강 서비스', 
                                            values='AMOUNT', 
                                            aggfunc='sum').fillna(0)

# 3. 결과 확인
print("--- 지역별 특정 정신건강 서비스 수혜 인원(MEMBERS) 현황 ---")
geo_service_members

# 4. 분석 결과 저장 (QGIS나 엑셀에서 활용 가능)
geo_service_members.to_csv("geo_service_members_matrix.csv")

geo_service_members.head()
# Out:
# --- 지역별 특정 정신건강 서비스 수혜 인원(MEMBERS) 현황 ---
# 특정 정신건강 서비스  ADULT_RESIDENTIAL_TX_SVCS       ALL  BH_PREVENTION_EDUCATION_SVC  \
# GEOGRAPHY
# Alameda                          0.000 32803.000                        0.000
# Alpine                           0.000     0.000                        0.000
# Amador                           0.000  2000.000                        0.000
# Butte                            0.000 27373.000                        0.000
# Calaveras                        0.000  7230.000                        0.000
#
# 특정 정신건강 서비스  CASE_MANAGEMENT/BROKERAGE  CRISIS_INTERVENTION  \
# GEOGRAPHY
# Alameda                       3520.000              844.000
# Alpine                           0.000                0.000
# Amador                           0.000                0.000
# Butte                         4258.000              424.000
# Calaveras                     1000.000                0.000
#
# 특정 정신건강 서비스  CRISIS_RESIDENTIAL_TX_SVCS  CRISIS_STABILIZATION  FULL_DAY_REHAB  \
# GEOGRAPHY
# Alameda                           0.000              1054.000           0.000
# Alpine                            0.000                 0.000           0.000
# Amador                            0.000                 0.000           0.000
# Butte                             0.000                 0.000           0.000
# Calaveras                         0.000                 0.000           0.000
#
# 특정 정신건강 서비스  FULL_DAY_TX_INTENSIVE       ICC     IHBS  INPATIENT_ADMIN  \
# GEOGRAPHY
# Alameda                      0.000 25973.000 3169.000            0.000
# Alpine                       0.000     0.000    0.000            0.000
# Amador                       0.000  1610.000 1250.000            0.000
# Butte                        0.000 23163.000 7054.000            0.000
# Calaveras                    0.000  5884.000 1749.000            0.000
#
# 특정 정신건강 서비스  MEDICATION_SUPPORT_SVCS  MENTAL_HEALTH_SVCS  MOBILE_CRISIS  \
# GEOGRAPHY
# Alameda                     2619.000            7955.000          0.000
# Alpine                         0.000               0.000          0.000
# Amador                         0.000            1064.000          0.000
# Butte                       3165.000            8257.000          0.000
# Calaveras                    603.000            1858.000          0.000
#
# 특정 정신건강 서비스  PSYCHIATRIC_HEALTH_FACILITY  SDMC_HOSPITAL_INPATIENT  \
# GEOGRAPHY
# Alameda                            0.000                   93.000
# Alpine                             0.000                    0.000
# Amador                             0.000                    0.000
# Butte                              0.000                    0.000
# Calaveras                          0.000                    0.000
#
# 특정 정신건강 서비스  SELF_HELP_PEER_SVCS   TFC  THERAPEUTIC_BEHAVIORAL_SVCS
# GEOGRAPHY
# Alameda                    0.000 0.000                      170.000
# Alpine                     0.000 0.000                        0.000
# Amador                     0.000 0.000                        0.000
# Butte                      0.000 0.000                      154.000
# Calaveras                  0.000 0.000                        0.000

# %% [markdown]
# ### 지역별 특정 정신건상 서비스 이용 인구 수

# %%
# 1. MEMBERS만 필터링해서 피벗 테이블 생성 (이미 데이터프레임 객체임)
df_geo_members = d_2[d_2['AMOUNT_TYPE'] == 'MEMBERS'].pivot_table(
    index='GEOGRAPHY', 
    columns='특정 정신건강 서비스', 
    values='AMOUNT', 
    aggfunc='sum'
).fillna(0)

# 2. 인덱스로 설정된 GEOGRAPHY를 일반 컬럼으로 변환 (분석하기 더 편해짐)
df_geo_members = df_geo_members.reset_index()

# 3. 데이터프레임 확인
print(type(df_geo_members)) # <class 'pandas.core.frame.DataFrame'> 출력 확인
display(df_geo_members.head())
# Out:
# <class 'pandas.DataFrame'>
# 특정 정신건강 서비스  GEOGRAPHY  ADULT_RESIDENTIAL_TX_SVCS       ALL  \
# 0              Alameda                      0.000 32803.000
# 1               Alpine                      0.000     0.000
# 2               Amador                      0.000  2000.000
# 3                Butte                      0.000 27373.000
# 4            Calaveras                      0.000  7230.000
#
# 특정 정신건강 서비스  BH_PREVENTION_EDUCATION_SVC  CASE_MANAGEMENT/BROKERAGE  \
# 0                                  0.000                   3520.000
# 1                                  0.000                      0.000
# 2                                  0.000                      0.000
# 3                                  0.000                   4258.000
# 4                                  0.000                   1000.000
#
# 특정 정신건강 서비스  CRISIS_INTERVENTION  CRISIS_RESIDENTIAL_TX_SVCS  \
# 0                        844.000                       0.000
# 1                          0.000                       0.000
# 2                          0.000                       0.000
# 3                        424.000                       0.000
# 4                          0.000                       0.000
#
# 특정 정신건강 서비스  CRISIS_STABILIZATION  FULL_DAY_REHAB  FULL_DAY_TX_INTENSIVE  \
# 0                        1054.000           0.000                  0.000
# 1                           0.000           0.000                  0.000
# 2                           0.000           0.000                  0.000
# 3                           0.000           0.000                  0.000
# 4                           0.000           0.000                  0.000
#
# 특정 정신건강 서비스       ICC     IHBS  INPATIENT_ADMIN  MEDICATION_SUPPORT_SVCS  \
# 0           25973.000 3169.000            0.000                 2619.000
# 1               0.000    0.000            0.000                    0.000
# 2            1610.000 1250.000            0.000                    0.000
# 3           23163.000 7054.000            0.000                 3165.000
# 4            5884.000 1749.000            0.000                  603.000
#
# 특정 정신건강 서비스  MENTAL_HEALTH_SVCS  MOBILE_CRISIS  PSYCHIATRIC_HEALTH_FACILITY  \
# 0                      7955.000          0.000                        0.000
# 1                         0.000          0.000                        0.000
# 2                      1064.000          0.000                        0.000
# 3                      8257.000          0.000                        0.000
# 4                      1858.000          0.000                        0.000
#
# 특정 정신건강 서비스  SDMC_HOSPITAL_INPATIENT  SELF_HELP_PEER_SVCS   TFC  \
# 0                             93.000                0.000 0.000
# 1                              0.000                0.000 0.000
# 2                              0.000                0.000 0.000
# 3                              0.000                0.000 0.000
# 4                              0.000                0.000 0.000
#
# 특정 정신건강 서비스  THERAPEUTIC_BEHAVIORAL_SVCS
# 0                                170.000
# 1                                  0.000
# 2                                  0.000
# 3                                154.000
# 4                                  0.000

# %% [markdown]
# ### icc_by_region
# ICC항목만 따로 골라서 지역 매칭

# %%
# 1. GEOGRAPHY와 ICC 컬럼만 추출하여 새로운 데이터프레임 생성
icc_by_region = df_geo_members[['GEOGRAPHY', 'ICC']]

# 2. 이용자 수가 많은 지역 순으로 정렬
icc_by_region = icc_by_region.sort_values(by='ICC', ascending=False)

# 3. 결과 확인 (상위 10개 지역)
print("--- 지역별 ICC 서비스 이용 인원 순위 ---")
print(icc_by_region.head(10))
# Out:
# --- 지역별 ICC 서비스 이용 인원 순위 ---
# 특정 정신건강 서비스       GEOGRAPHY        ICC
# 18              Los Angeles 764613.000
# 35           San Bernardino 355399.000
# 32                Riverside 300485.000
# 29                   Orange 218658.000
# 33               Sacramento 136747.000
# 36                San Diego  91687.000
# 38              San Joaquin  90053.000
# 42              Santa Clara  79403.000
# 54                  Ventura  62514.000
# 14                     Kern  62386.000

# %%
# 1. GEOGRAPHY와 ICC 컬럼만 추출하여 새로운 데이터프레임 생성
medication_by_region = df_geo_members[['GEOGRAPHY', 'MEDICATION_SUPPORT_SVCS']]

# 2. 이용자 수가 많은 지역 순으로 정렬
medication_by_region = medication_by_region.sort_values(by='MEDICATION_SUPPORT_SVCS', ascending=False)

# 3. 결과 확인 (상위 10개 지역)
print("--- 지역별 MEDICATION_SUPPORT_SVCS 서비스 이용 인원 순위 ---")
print(medication_by_region.head(10))


print(medication_by_region.columns)
# Out:
# --- 지역별 MEDICATION_SUPPORT_SVCS 서비스 이용 인원 순위 ---
# 특정 정신건강 서비스       GEOGRAPHY  MEDICATION_SUPPORT_SVCS
# 18              Los Angeles               111965.000
# 35           San Bernardino                53430.000
# 32                Riverside                23920.000
# 14                     Kern                21410.000
# 36                San Diego                20934.000
# 29                   Orange                17695.000
# 9                    Fresno                15914.000
# 38              San Joaquin                12460.000
# 6              Contra Costa                 9914.000
# 33               Sacramento                 8606.000
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\itwill\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '특정 정신건강 서비스'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[105], line 12
#       8 print("--- 지역별 MEDICATION_SUPPORT_SVCS 서비스 이용 인원 순위 ---")
#       9 print(medication_by_region.head(10))
# ---> 12 medication_by_region['특정 정신건강 서비스'].unique()
#
# File c:\Users\itwill\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:4378, in DataFrame.__getitem__(self, key)
#    4376 if self.columns.nlevels > 1:
#    4377     return self._getitem_multilevel(key)
# -> 4378 indexer = self.columns.get_loc(key)
#    4379 if is_integer(indexer):
#    4380     indexer = [indexer]
#
# File c:\Users\itwill\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: '특정 정신건강 서비스'

# %% [markdown]
# ### MEDICATION_only

# %% [markdown]
#  MEDICATION_SUPOORT_SVCS 서비스의 AMOUNT값을 지역별로 확인

# %%
# 'ICC' 컬럼과 'GEOGRAPHY' 컬럼만 선택
MEDICATION_only = medication_by_region[['GEOGRAPHY', 'MEDICATION_SUPPORT_SVCS']]
MEDICATION_only
# Out:
# 특정 정신건강 서비스        GEOGRAPHY  MEDICATION_SUPPORT_SVCS
# 18               Los Angeles               111965.000
# 35            San Bernardino                53430.000
# 32                 Riverside                23920.000
# 14                      Kern                21410.000
# 36                 San Diego                20934.000
# 29                    Orange                17695.000
# 9                     Fresno                15914.000
# 38               San Joaquin                12460.000
# 6               Contra Costa                 9914.000
# 33                Sacramento                 8606.000
# 48                Stanislaus                 8528.000
# 16                      Lake                 7440.000
# 54                   Ventura                 6259.000
# 12                  Imperial                 5341.000
# 55                      Yolo                 3853.000
# 39           San Luis Obispo                 3836.000
# 3                      Butte                 3165.000
# 0                    Alameda                 2619.000
# 11                  Humboldt                 2477.000
# 49               Sutter/Yuba                 1988.000
# 52                    Tulare                 1710.000
# 44                    Shasta                 1697.000
# 41             Santa Barbara                 1440.000
# 40                 San Mateo                 1313.000
# 20                     Marin                  788.000
# 15                     Kings                  776.000
# 4                  Calaveras                  603.000
# 47                    Sonoma                  514.000
# 23                    Merced                  494.000
# 46                    Solano                  354.000
# 19                    Madera                  272.000
# 30                    Placer                  200.000
# 27                      Napa                   47.000
# 45                  Siskiyou                   40.000
# 50                    Tehama                    0.000
# 51                   Trinity                    0.000
# 53                  Tuolumne                    0.000
# 2                     Amador                    0.000
# 43                Santa Cruz                    0.000
# 42               Santa Clara                    0.000
# 17                    Lassen                    0.000
# 37             San Francisco                    0.000
# 5                     Colusa                    0.000
# 7                  Del Norte                    0.000
# 8                  El Dorado                    0.000
# 10                     Glenn                    0.000
# 34                San Benito                    0.000
# 13                      Inyo                    0.000
# 31                    Plumas                    0.000
# 1                     Alpine                    0.000
# 26                  Monterey                    0.000
# 25                      Mono                    0.000
# 24                     Modoc                    0.000
# 22                 Mendocino                    0.000
# 21                  Mariposa                    0.000
# 28                    Nevada                    0.000

# %%
print(medication_by_region.columns)
# Out:
# Index(['GEOGRAPHY', 'MEDICATION_SUPPORT_SVCS'], dtype='str', name='특정 정신건강 서비스')

# %%
members_df['특정 정신건강 서비스'].unique()
# Out:
# <StringArray>
# [                        'ALL',   'CASE_MANAGEMENT/BROKERAGE',
#          'CRISIS_INTERVENTION',  'CRISIS_RESIDENTIAL_TX_SVCS',
#         'CRISIS_STABILIZATION',       'FULL_DAY_TX_INTENSIVE',
#                          'ICC',                        'IHBS',
#              'INPATIENT_ADMIN',     'MEDICATION_SUPPORT_SVCS',
#           'MENTAL_HEALTH_SVCS', 'PSYCHIATRIC_HEALTH_FACILITY',
#      'SDMC_HOSPITAL_INPATIENT', 'THERAPEUTIC_BEHAVIORAL_SVCS',
#                          'TFC',              'FULL_DAY_REHAB',
#    'ADULT_RESIDENTIAL_TX_SVCS', 'BH_PREVENTION_EDUCATION_SVC',
#          'SELF_HELP_PEER_SVCS',               'MOBILE_CRISIS']
# Length: 20, dtype: str

# %% [markdown]
# ### monthly_trend<br>
#
# STATE 제거 후

# %%
# RPT_DATE를 날짜 형식으로 변환 (이미 하셨다면 통과)
d_2['RPT_DATE'] = pd.to_datetime(df1['RPT_DATE'])

# 특정 서비스(예: ICC)의 월별 이용량 추이 추출
time_series = d_2[d_2['특정 정신건강 서비스'] == 'ICC'].set_index('RPT_DATE')
monthly_trend = time_series['AMOUNT'].resample('MS').sum()

d_2
# Out:
#         RPT_DATE  RPT_YR GEOGRAPHY                  특정 정신건강 서비스      AMOUNT  \
# 0     2020-06-30  FY1920   Alameda                          ALL     410.000
# 1     2020-06-30  FY1920   Alameda                          ALL 4582253.000
# 2     2020-06-30  FY1920   Alameda    CASE_MANAGEMENT/BROKERAGE      59.000
# 3     2020-06-30  FY1920   Alameda    CASE_MANAGEMENT/BROKERAGE   28843.000
# 4     2020-06-30  FY1920   Alameda    CASE_MANAGEMENT/BROKERAGE   67459.000
# ...          ...     ...       ...                          ...         ...
# 94918 2025-12-02  FY2425      Yolo          SELF_HELP_PEER_SVCS       0.000
# 94919 2025-12-02  FY2425      Yolo          SELF_HELP_PEER_SVCS       0.000
# 94920 2025-12-02  FY2425      Yolo  THERAPEUTIC_BEHAVIORAL_SVCS       0.000
# 94921 2025-12-02  FY2425      Yolo  THERAPEUTIC_BEHAVIORAL_SVCS       0.000
# 94922 2025-12-02  FY2425      Yolo  THERAPEUTIC_BEHAVIORAL_SVCS       0.000
#
#        AMOUNT_ANNOT AMOUNT_TYPE
# 0             0.000     MEMBERS
# 1             0.000     DOLLARS
# 2             0.000     MEMBERS
# 3             0.000     MINUTES
# 4             0.000     DOLLARS
# ...             ...         ...
# 94918         2.000     MINUTES
# 94919         2.000     DOLLARS
# 94920         1.000     DOLLARS
# 94921         1.000     MEMBERS
# 94922         1.000     MINUTES
#
# [90519 rows x 7 columns]

# %%
# 1. 제거 전 지역별 합계 (d_1)
summary_before = d_1.groupby("GEOGRAPHY")["AMOUNT"].sum().reset_index()
summary_before.columns = ["GEOGRAPHY", "제거 전 합계"]

# 2. 제거 후 지역별 합계 (d_2)
summary_after = d_2.groupby("GEOGRAPHY")["AMOUNT"].sum().reset_index()
summary_after.columns = ["GEOGRAPHY", "제거 후 합계"]

# 3. 두 데이터프레임 병합 (Left Join)
# 제거 전 데이터에는 'STATE'가 있고 제거 후에는 없으므로, 'how=left'를 사용합니다.
comparison_df = pd.merge(summary_before, summary_after, on="GEOGRAPHY", how="left")

# 4. 결측치 처리 및 차이 열 추가
# 제거 후 데이터에서 'STATE'는 NaN이 되므로 0으로 채워줍니다.
comparison_df["제거 후 합계"] = comparison_df["제거 후 합계"].fillna(0)
comparison_df["차이(Difference)"] = comparison_df["제거 전 합계"] - comparison_df["제거 후 합계"]

# 5. 결과 확인 (차이가 큰 순서대로 나열)
print(comparison_df.sort_values(by="차이(Difference)", ascending=False).head())
comparison_df
# Out:
#     GEOGRAPHY         제거 전 합계        제거 후 합계  차이(Difference)
# 33      STATE 54717357323.784          0.000 54717357323.784
# 37  San Diego  1909096027.090 1909095907.090         120.000
# 0     Alameda   657416388.830  657416388.830           0.000
# 29     Orange  2459924849.340 2459924849.340           0.000
# 31     Plumas      897767.000     897767.000           0.000
#           GEOGRAPHY         제거 전 합계         제거 후 합계  차이(Difference)
# 0           Alameda   657416388.830   657416388.830           0.000
# 1            Alpine           0.000           0.000           0.000
# 2            Amador    27303829.040    27303829.040           0.000
# 3             Butte   319377550.860   319377550.860           0.000
# 4         Calaveras    55923048.010    55923048.010           0.000
# 5            Colusa      163184.000      163184.000           0.000
# 6      Contra Costa  1753764794.100  1753764794.100           0.000
# 7         Del Norte     6522417.000     6522417.000           0.000
# 8         El Dorado   202393177.340   202393177.340           0.000
# 9            Fresno  1058152270.490  1058152270.490           0.000
# 10            Glenn    70533162.740    70533162.740           0.000
# 11         Humboldt   311511189.510   311511189.510           0.000
# 12         Imperial   194994336.310   194994336.310           0.000
# 13             Inyo    15526428.630    15526428.630           0.000
# 14             Kern  1163927416.890  1163927416.890           0.000
# 15            Kings   213465780.800   213465780.800           0.000
# 16             Lake   126896704.540   126896704.540           0.000
# 17           Lassen     1362209.860     1362209.860           0.000
# 18      Los Angeles 23106285649.290 23106285649.290           0.000
# 19           Madera    90255403.090    90255403.090           0.000
# 20            Marin   202340355.100   202340355.100           0.000
# 21         Mariposa    74729868.120    74729868.120           0.000
# 22        Mendocino   145293007.700   145293007.700           0.000
# 23           Merced   400727109.690   400727109.690           0.000
# 24            Modoc    13552551.660    13552551.660           0.000
# 25             Mono           0.000           0.000           0.000
# 26         Monterey   169485665.260   169485665.260           0.000
# 27             Napa    84232246.110    84232246.110           0.000
# 28           Nevada   233067661.590   233067661.590           0.000
# 29           Orange  2459924849.340  2459924849.340           0.000
# 30           Placer   222088310.210   222088310.210           0.000
# 31           Plumas      897767.000      897767.000           0.000
# 32        Riverside  3285196902.150  3285196902.150           0.000
# 33            STATE 54717357323.784           0.000 54717357323.784
# 34       Sacramento  1357521571.980  1357521571.980           0.000
# 35       San Benito     3069552.000     3069552.000           0.000
# 36   San Bernardino  4525430570.350  4525430570.350           0.000
# 37        San Diego  1909096027.090  1909095907.090         120.000
# 38    San Francisco   818209191.930   818209191.930           0.000
# 39      San Joaquin  1054211854.800  1054211854.800           0.000
# 40  San Luis Obispo   821297296.680   821297296.680           0.000
# 41        San Mateo   148112876.120   148112876.120           0.000
# 42    Santa Barbara   464959404.590   464959404.590           0.000
# 43      Santa Clara  3100309671.500  3100309671.500           0.000
# 44       Santa Cruz    82067687.020    82067687.020           0.000
# 45           Shasta   216100800.570   216100800.570           0.000
# 46         Siskiyou    42184248.670    42184248.670           0.000
# 47           Solano   329003596.180   329003596.180           0.000
# 48           Sonoma   192096128.780   192096128.780           0.000
# 49       Stanislaus   813064410.470   813064410.470           0.000
# 50      Sutter/Yuba   207823974.310   207823974.310           0.000
# 51           Tehama      287771.520      287771.520           0.000
# 52          Trinity     3859721.640     3859721.640           0.000
# 53           Tulare   145289917.570   145289917.570           0.000
# 54         Tuolumne     4140078.000     4140078.000           0.000
# 55          Ventura   858772785.630   858772785.630           0.000
# 56             Yolo   304127602.580   304127602.580           0.000

# %% [markdown]
# >주요 코드:  .columns<br>
#
# >STATE 제거 전 합계 (d_1): 약 $5.4717 \times 10^{10}$ (약 547억)<br>
# >STATE 제거 후 합계 (d_2): $0.0$ (정상적으로 제거됨)<br>
# >차이 (Difference): 약 $5.4717 \times 10^{10}$<br>
#
# >결측치가 0인 행들은 데이터 전처리가 훌륭하게 된 칼럼
# 즉, GEOGRAPHY의 STATE값에만 거대한 값이 포함

# %% [markdown]
# ### mean_comparison
#
# STATE 제거 전, 후에 따른 AMOUNT값의 전체 평균 비교

# %%
import pandas as pd

# 1. STATE가 포함된 데이터(df1)와 제거된 데이터(d_2)의 평균 계산
# numeric_only=True를 사용하여 수치형 컬럼인 AMOUNT에 대해서만 계산합니다.
mean_before = df1['AMOUNT'].mean()
mean_after = d_2['AMOUNT'].mean()

# 2. 결과를 보기 좋게 데이터프레임으로 정리
mean_comparison = pd.DataFrame({
    "분석 대상": ["STATE 제거 전 (df1)", "STATE 제거 후 (d_2)"],
    "AMOUNT 전체 평균": [mean_before, mean_after]
})

# 3. 평균의 차이 계산하여 출력
diff = mean_before - mean_after

print("--- [AMOUNT] 컬럼 전체 평균 비교 ---")
print(mean_comparison)
print(f"\n평균 차이(Difference): {diff:,.2f}")

mean_comparison
# Out:
# --- [AMOUNT] 컬럼 전체 평균 비교 ---
#               분석 대상  AMOUNT 전체 평균
# 0  STATE 제거 전 (df1)   1146041.584
# 1  STATE 제거 후 (d_2)    597248.925
#
# 평균 차이(Difference): 548,792.66
#               분석 대상  AMOUNT 전체 평균
# 0  STATE 제거 전 (df1)   1146041.584
# 1  STATE 제거 후 (d_2)    597248.925

# %%
import matplotlib.pyplot as plt

# 1. RPT_DATE를 날짜 형식으로 변환 (d_2에 적용)
d_2['RPT_DATE'] = pd.to_datetime(d_2['RPT_DATE'])

# 2. 특정 서비스(예: ICC)와 특정 단위(예: MEMBERS) 필터링
# 단위를 고정하지 않으면 시간(MINUTES)과 인원(MEMBERS)이 합쳐져 수치가 왜곡될 수 있습니다.
target_service = 'ICC' 
target_type = 'MEMBERS'

filtered_data = d_2[(d_2['특정 정신건강 서비스'] == target_service) & 
                    (d_2['AMOUNT_TYPE'] == target_type)]

# 3. 날짜를 인덱스로 설정하고 월별 합계 계산
monthly_trend = filtered_data.set_index('RPT_DATE')['AMOUNT'].resample('MS').sum()

# 4. 선 그래프 시각화
plt.figure(figsize=(12, 6))
monthly_trend.plot(marker='o', color='b', linestyle='-')

plt.title(f'Monthly Trend of {target_service} ({target_type}) - State Excluded', fontsize=14)
plt.xlabel('Date')
plt.ylabel('Total Amount')
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# # members_only
# AMOUNT_TYPE 값 중 MEMBERS값 기준으로 GEOGRAPHY 순위

# %%
# 1. 'MEMBERS'(이용자 수) 단위만 필터링
members_only = d_2[d_2['AMOUNT_TYPE'] == 'MEMBERS']

# 2. 지역별(GEOGRAPHY)로 이용자 수 합계 계산
geo_member_ranking = members_only.groupby('GEOGRAPHY')['AMOUNT'].sum().reset_index()

# 3. 이용자 수가 많은 순서대로 정렬
geo_member_ranking = geo_member_ranking.sort_values(by='AMOUNT', ascending=False)

# 4. 결과 확인 (상위 10개 지역)
print("--- 캘리포니아 카운티별 이용자 수(MEMBERS) 순위 ---")
geo_member_ranking

# 5. QGIS 활용을 위한 CSV 저장
geo_member_ranking.to_csv("county_members_ranking.csv", index=False)

geo_member_ranking.head()
# Out:
# --- 캘리포니아 카운티별 이용자 수(MEMBERS) 순위 ---
#          GEOGRAPHY      AMOUNT
# 18     Los Angeles 2705419.000
# 35  San Bernardino 1011860.000
# 32       Riverside  924273.000
# 29          Orange  668313.000
# 33      Sacramento  373421.000

# %% [markdown]
# ### service_members_only<br>
# MEMBERS행에 해당하는 항목<br>
# 실제로 몇 명의 아이들이 이 서비스를 받았는가

# %%
# 'AMOUNT_TYPE' 컬럼의 값이 'MEMBERS'인 행만 추출
service_members_only = service_type_summary[service_type_summary['AMOUNT_TYPE']=='MEMBERS']

# 이용자 수가 많은 순서대로 정렬 (선택 사항)
service_members_only = service_members_only.sort_values(by='AMOUNT', ascending=False) 

# 결과 확인
print("--- 특정 정신건강 서비스별 이용자 수(MEMBERS) 현황 ---")
service_members_only.head()
# Out:
# --- 특정 정신건강 서비스별 이용자 수(MEMBERS) 현황 ---
#                   특정 정신건강 서비스 AMOUNT_TYPE      AMOUNT  AMOUNT_ANNOT
# 4                         ALL     MEMBERS 3136700.000       486.000
# 27                        ICC     MEMBERS 2635321.000       795.000
# 30                       IHBS     MEMBERS  956146.000       625.000
# 39         MENTAL_HEALTH_SVCS     MEMBERS  948020.000       731.000
# 9   CASE_MANAGEMENT/BROKERAGE     MEMBERS  378131.000      1013.000

# %%
d_2['AMOUNT'].describe()
# Out:
# count       90529.000
# mean       597248.925
# std       4529922.614
# min             0.000
# 25%             0.000
# 50%           179.000
# 75%         90003.920
# max     144094010.000
# Name: AMOUNT, dtype: float64

# %%
d_2['AMOUNT_TYPE'].describe()
# Out:
# count       90519
# unique          5
# top       MEMBERS
# freq        31714
# Name: AMOUNT_TYPE, dtype: object

# %% [markdown]
# > AMOUNT_TYPE 컬럼에 describe()를 적용했을 때 수치가 아닌 count, unique, top, freq 같은 값이 나오는 이유는 이 컬럼이 숫자가 아닌 문자열(범주형/Object) 데이터이기 때문입니다.
#
# > 판다스의 describe() 함수는 데이터의 타입에 따라 다른 결과를 보여줍니다.
#
# 1. 결과값의 의미 해석
# 출력된 결과의 각 항목은 다음과 같은 의미를 담고 있습니다.
#
# count: 결측치를 제외한 전체 행의 개수입니다.
#
# unique: 중복을 제거한 항목의 종류 수입니다. (예: MEMBERS, MINUTES, DOLLARS 등 총 4~5종류가 있다면 '4' 또는 '5'로 표시됩니다.)
#
# top: 데이터에서 가장 많이 등장한 항목 이름입니다.
#
# freq: 'top' 항목이 전체 데이터에서 몇 번이나 등장했는지 나타내는 빈도수입니다.

# %% [markdown]
# ----------------------------------------------------------------------------
# AMOUNT (약264만): 이 수치는 해당 기간 동안 집계된 전체 서비스량(인원, 시간 등)의 총합입니다. 200만이 넘는 수치는 매우 큰 규모를 나타냅니다.
#
# AMOUNT_ANNOT (795): 이 수치는 '개인정보 보호를 위해 실제 값을 숨긴(Masking) 횟수'의 총합입니다.
#
# 수치적 비중: 260만이라는 거대한 AMOUNT에 비해 AMOUNT_ANNOT은 고작 795에 불과합니다. 이는 전체 데이터 중 극히 일부(약 0.03%)만 보안 처리가 되었다는 뜻입니다.
#
# ---------------------------------------------------------------------------
#
# AMOUNT: 5,000 (매우 낮음)
#
# AMOUNT_ANNOT: 4,500 (매우 높음)
#
# 해석: 이 서비스는 보고되는 거의 모든 케이스가 11명 미만이라서 실제 숫자가 다 가려지고 AMOUNT_ANNOT 점수만 쌓인 것입니다. 데이터상으로는 작아 보이지만, 실제로는 아주 소수의 아이들에게만 제공되는 고도로 특수화된 서비스임을 시사합니다.

# %% [markdown]
#  - 어떤 값이 가장 영향을 많이 미칠까...?
#  AMOUNT

# %% [markdown]
# ###

# %% [markdown]
# 목표선정<br>
# ![image.png](attachment:image.png)

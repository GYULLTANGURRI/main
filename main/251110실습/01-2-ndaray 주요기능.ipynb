# %%
import numpy as np

# %%
# 1.
score = [72.5, 88, 91.5, 67.0, 80.0, 59.5]
myarr1 = np.array(score, dtype = 'int')
myarr1
# Out:
# array([72, 88, 91, 67, 80, 59])

# %%
# 2.
score = [72.5, 88, 91.5, 67.0, 80.0, 59.5]
score = np.array(score)


students = score[score >= 80]
print(students)
# Out:
# [88.  91.5 80. ]

# %%
# 3.
score = np.array([72.5, 88, 91.5, 67.0, 80.0, 59.5])
conditions = [
    (score >= 90),
     (score >= 80),
     (score >= 70)
     
]

value = ['A','B','C']

result = np.select(conditions, value, default = 'F')
result
# Out:
# array(['C', 'B', 'A', 'F', 'B', 'F'], dtype='<U1')

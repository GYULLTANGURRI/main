# %%
import numpy as np

# %%
arr = np.array([10, 20, 30, 40, 50])

ar = len(arr)
print("배열의 길이:", ar)
print("첫 번째 원소:", arr[0])
for i, v in enumerate(arr):
    print("%d 번째 원소 >> %d" % (i,v))
# Out:
# 배열의 길이: 5
# 첫 번째 원소: 10
# 0 번째 원소 >> 10
# 1 번째 원소 >> 20
# 2 번째 원소 >> 30
# 3 번째 원소 >> 40
# 4 번째 원소 >> 50

# %%
from hossam import load_data, load_info

# %%
load_info()
# Out:
#        name                             desc  \
# 0     grade       어느 학급의 과목별 점수를 조사한 가상의 데이터
# 1  ad_sales  어느 회사의 월별 광고액과 매출액을 조사한 가상의 데이터
#
#                                          url
# 0     https://data.hossam.kr/data/grade.xlsx
# 1  https://data.hossam.kr/data/ad-sales.xlsx

# %%
load_data("ad_sales")
# Out:
# [data] https://data.hossam.kr/data/ad-sales.xlsx
# [desc] 어느 회사의 월별 광고액과 매출액을 조사한 가상의 데이터
#
# field     description
# --------  --------------
# month     월
# revenue   매출액(억원)
# expenses  광고비(백만원)
#        revenue  expenses
# month
# 1월           2       100
# 2월         142      1690
# 3월         122       298
# 4월         130       390
# 5월         185       590
# 6월         121       200
# 7월         101       190
# 8월         199       460
# 9월         221       660
# 10월        139       350
# 11월        169       650
# 12월        237       880

# %%
origin = load_data('grade')
origin
# Out:
# [data] https://data.hossam.kr/data/grade.xlsx
# [desc] 어느 학급의 과목별 점수를 조사한 가상의 데이터
#
# field    description
# -------  -------------
# 이름     index
# 학년     int
# 성별     str
# 국어     int
# 영어     int
# 수학     int
# 과학     int
#     학년  성별  국어   영어  수학  과학
# 이름
# 철수   1  남자  98   77  88  64
# 영희   2  여자  88  120  62  72
# 민철   1  남자  92   70  83  79
# 수현   3  여자  63   60  31  71
# 호영   4  남자  75   50  90  88
# 영호   4  남자  80   88  91  72
# 용식   2  남자  82   88  79  90
# 나영   1  여자  90   92  81  95
# 석영   1  남자  91   90  89  80

# %%
print("차원:", origin.ndim)
print("크기:", origin.shape)
# Out:
# 차원: 2
# 크기: (9, 6)

# %%
origin.dtypes
# Out:
# 학년     int64
# 성별    object
# 국어     int64
# 영어     int64
# 수학     int64
# 과학     int64
# dtype: object

# %%
origin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9 entries, 철수 to 석영
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   학년      9 non-null      int64
#  1   성별      9 non-null      object
#  2   국어      9 non-null      int64
#  3   영어      9 non-null      int64
#  4   수학      9 non-null      int64
#  5   과학      9 non-null      int64
# dtypes: int64(5), object(1)
# memory usage: 504.0+ bytes

# %%
origin['국어']
# Out:
# 이름
# 철수    98
# 영희    88
# 민철    92
# 수현    63
# 호영    75
# 영호    80
# 용식    82
# 나영    90
# 석영    91
# Name: 국어, dtype: int64

# %%
type(origin['국어'])
# Out:
# pandas.core.series.Series

# %%
df2 = origin[['국어','영어','수학']]
df2
# Out:
#     국어   영어  수학
# 이름
# 철수  98   77  88
# 영희  88  120  62
# 민철  92   70  83
# 수현  63   60  31
# 호영  75   50  90
# 영호  80   88  91
# 용식  82   88  79
# 나영  90   92  81
# 석영  91   90  89

# %%
origin.loc['철수']
# Out:
# 학년     1
# 성별    남자
# 국어    98
# 영어    77
# 수학    88
# 과학    64
# Name: 철수, dtype: object

# %%
type(origin.loc['철수'])
# Out:
# pandas.core.series.Series

# %%
origin.iloc[0]
# Out:
# 학년     1
# 성별    남자
# 국어    98
# 영어    77
# 수학    88
# 과학    64
# Name: 철수, dtype: object

# %%
origin.iloc[1:4]
# Out:
#     학년  성별  국어   영어  수학  과학
# 이름
# 영희   2  여자  88  120  62  72
# 민철   1  남자  92   70  83  79
# 수현   3  여자  63   60  31  71

# %%
origin['국어']['철수']
# Out:
# np.int64(98)

# %%
origin.loc['철수','국어']
# Out:
# np.int64(98)

# %%
origin.iloc[1,2]
# Out:
# np.int64(88)

# %%
origin.iloc[:, 3]
# Out:
# 이름
# 철수     77
# 영희    120
# 민철     70
# 수현     60
# 호영     50
# 영호     88
# 용식     88
# 나영     92
# 석영     90
# Name: 영어, dtype: int64

# %%
origin.loc['철수','국어'] = 100
origin
# Out:
#     학년  성별   국어   영어  수학  과학
# 이름
# 철수   1  남자  100   77  88  64
# 영희   2  여자   88  120  62  72
# 민철   1  남자   92   70  83  79
# 수현   3  여자   63   60  31  71
# 호영   4  남자   75   50  90  88
# 영호   4  남자   80   88  91  72
# 용식   2  남자   82   88  79  90
# 나영   1  여자   90   92  81  95
# 석영   1  남자   91   90  89  80

# %%
origin.head(2)
# Out:
#     학년  성별   국어   영어  수학  과학
# 이름
# 철수   1  남자  100   77  88  64
# 영희   2  여자   88  120  62  72

# %%
origin.tail(2)
# Out:
#     학년  성별  국어  영어  수학  과학
# 이름
# 나영   1  여자  90  92  81  95
# 석영   1  남자  91  90  89  80

# %%
print("합계:",origin['국어'].sum())
print("최댓값:",origin['국어'].max())
print("최솟값:",origin['국어'].min())
print("분산:",origin['국어'].var())
print("표준편차:",origin['국어'].std())
print("중앙값:",origin['국어'].median())
print("1사분위수",origin['국어'].quantile(0.25))
print("2사분위수",origin['국어'].quantile(0.5))
print("3사분위수",origin['국어'].quantile(0.75))
# Out:
# 합계: 761
# 최댓값: 100
# 최솟값: 63
# 분산: 120.02777777777779
# 표준편차: 10.955718953029864
# 중앙값: 88.0
# 1사분위수 80.0
# 2사분위수 88.0
# 3사분위수 91.0

# %%
origin.sum()
# Out:
# 학년                    19
# 성별    남자여자남자여자남자남자남자여자남자
# 국어                   761
# 영어                   735
# 수학                   694
# 과학                   711
# dtype: object

# %%
origin['국어'].describe()
# Out:
# count      9.000000
# mean      84.555556
# std       10.955719
# min       63.000000
# 25%       80.000000
# 50%       88.000000
# 75%       91.000000
# max      100.000000
# Name: 국어, dtype: float64

# %%
df2 = origin[['국어','영어','수학','과학']]
desc = df2.describe()
desc
# Out:
#                국어          영어         수학         과학
# count    9.000000    9.000000   9.000000   9.000000
# mean    84.555556   81.666667  77.111111  79.000000
# std     10.955719   20.481699  19.451507  10.283482
# min     63.000000   50.000000  31.000000  64.000000
# 25%     80.000000   70.000000  79.000000  72.000000
# 50%     88.000000   88.000000  83.000000  79.000000
# 75%     91.000000   90.000000  89.000000  88.000000
# max    100.000000  120.000000  91.000000  95.000000

# %%
t = desc.T
t
# Out:
#     count       mean        std   min   25%   50%   75%    max
# 국어    9.0  84.555556  10.955719  63.0  80.0  88.0  91.0  100.0
# 영어    9.0  81.666667  20.481699  50.0  70.0  88.0  90.0  120.0
# 수학    9.0  77.111111  19.451507  31.0  79.0  83.0  89.0   91.0
# 과학    9.0  79.000000  10.283482  64.0  72.0  79.0  88.0   95.0

# %%
origin['성별'].value_counts()
# Out:
# 성별
# 남자    6
# 여자    3
# Name: count, dtype: int64

# %%
origin['학년'].value_counts()
# Out:
# 학년
# 1    4
# 2    2
# 4    2
# 3    1
# Name: count, dtype: int64
